# %%
from qiskit import QuantumCircuit, BasicAer, execute
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_bloch_vector

from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_state_city
from qiskit.visualization import plot_state_hinton
from qiskit.visualization import plot_state_paulivec
from qiskit.visualization import plot_state_qsphere

# %matplotlib inline

# %%
qc = QuantumCircuit(2,2)
qc.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend).result()
plot_bloch_multivector(job.get_statevector(qc), title="Initial State")

# %%
plot_state_qsphere(job.get_statevector(qc))

# %%
qc.h(0)

qc.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend).result()
plot_bloch_multivector(job.get_statevector(qc), title="Hadamard to  qubit 1")

# %%
plot_state_qsphere(job.get_statevector(qc))

# %%
qc.cx(0, 1)
qc.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend).result()
plot_bloch_multivector(job.get_statevector(qc), title="Cnot on q0")

# %%
plot_state_qsphere(job.get_statevector(qc))

# %%
qc.measure([0, 1], [0, 1])
qc.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend).result()
plot_bloch_multivector(job.get_statevector(qc), title="After measurement")

# %%
plot_state_qsphere(job.get_statevector(qc))

# %%
backend = BasicAer.get_backend('qasm_simulator')
job = execute(qc, backend)
plot_histogram(job.result().get_counts(), color='midnightblue', title="New Histogram")

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend).result()
plot_state_city(job.get_statevector(qc), color=['midnightblue', 'midnightblue'],
     title="New State City")

# %%
plot_state_hinton(job.get_statevector(qc), title="New Hinton Plot")

# %%
plot_state_paulivec(job.get_statevector(qc), color='midnightblue',
     title="New PauliVec plot")

# %%
plot_state_qsphere(job.get_statevector(qc))
