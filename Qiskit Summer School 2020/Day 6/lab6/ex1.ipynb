# %% [markdown]
# ![image](resources/qgss-header.png)

# %% [markdown]
# # Lab 6: Qubit Drive: Rabi & Ramsey Experiments

# %% [markdown]
# In this lab, you will take what you learned about qubit drive to perform Rabi and Ramsey experiment on a Pulse Simulator. The goal of this lab is to familiarize yourself with the important concepts of manipulating qubit states with microwave pulses.

# %% [markdown]
# ### Installing Necessary Packages
# Before we begin, you will need to install some prerequisites into your environment. Run the cell below to complete these installations. At the end, the cell outputs will be cleared.

# %%
# !pip install -U -r grading_tools/requirements.txt

from IPython.display import clear_output
clear_output()

# %% [markdown]
# ## Simulating the Transmon as a Duffing Oscillator

# %% [markdown]
# As you learned in Lecture 6, the transmon can be understood as a Duffing oscillator specified by a frequency $\nu$, anharmonicity $\alpha$, and drive strength $r$, which results in the Hamiltonian
# $$
#    \hat{H}_{\rm Duff}/\hbar = 2\pi\nu a^\dagger a + \pi \alpha a^\dagger a(a^\dagger a - 1) + 2 \pi r (a + a^\dagger) \times D(t),
# $$
#
# where $D(t)$ is the signal on the drive channel for the qubit, and $a^\dagger$ and $a$ are, respectively, the creation and annihilation operators for the qubit. Note that the drive strength $r$ sets the scaling of the control term, with $D(t)$ assumed to be a complex and unitless number satisfying $|D(t)| \leq 1$.

# %% [markdown]
# ## Qiskit Pulse Overview
#
# As a brief overview, Qiskit Pulse schedules (experiments) consist of Instructions (i.e., Play) acting on Channels (i.e., the drive channel). Here is a summary table of available Instructions and Channels:
#
# ![image](resources/pulse-instr.png)
#
# For more detail, this table summarizes the interaction of the channels with the actual quantum hardware:
#
# ![image](resources/pulse-user-device-layers.png)
#
# However, we find it is more instructive to begin with guided programming in Pulse. Below you will learn how to create pulses, schedules, and run experiments on a simulator. These lessons can be immediately applied to actual pulse-enabled quantum hardware, in particular [`ibmq_armonk`](https://www.ibm.com/blogs/research/2019/12/qiskit-openpulse/).

# %% [markdown]
# ## Let's get started!

# %% [markdown]
# In most of the cells below, nothing needs to be modified. **However, you will need to execute the cells by pressing `shift+Enter` in each code block**. In order to keep things tidy and focus on the important aspects of Qiskit Pulse, the following cells make use of methods from the `helper` module. For the gory details, please refer back to the [Lab 6 notebook](lab6-drive-ham-rabi-ramsey.ipynb). Before coming to Exercise 1a, the following code blocks
#
# - create backend pulse simulator and instantiate the transmon as a Duffing oscillator of frequency $\sim 5$ GHz
# - import libraries for numerics and visualization, and define helpful constants
# - create the channels for the pulse schedule and define measurment schedule (we will only work with the drive channel)

# %%
# our backend is the Pulse Simulator
from resources import helper
from qiskit.providers.aer import PulseSimulator
backend_sim = PulseSimulator()

# sample duration for pulse instructions 
dt = 1e-9

# create the model
duffing_model = helper.get_transmon(dt)

# get qubit frequency from Duffing model
qubit_lo_freq = duffing_model.hamiltonian.get_qubit_lo_from_drift()

# %%
print(duffing_model)
print(qubit_lo_freq)
# Out:
# <qiskit.providers.aer.pulse.pulse_system_model.PulseSystemModel object at 0x7f96facc3c10>
# [5042000000.0]

# %%
import numpy as np

# visualization tools
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# unit conversion factors -> all backend properties returned in SI (Hz, sec, etc)
GHz = 1.0e9 # Gigahertz
MHz = 1.0e6 # Megahertz
kHz = 1.0e3 # kilohertz
us = 1.0e-6 # microseconds
ns = 1.0e-9 # nanoseconds

# %% [markdown]
# ### Instantiate channels and create measurement schedule
#
# We will use the same measurement schedule throughout, whereas the drive schedules will vary. This must be built for the simulator, for a real backend we can ask for its default measurement pulse.

# %%
from qiskit import pulse
from qiskit.pulse import Play, Acquire
from qiskit.pulse.pulse_lib import GaussianSquare

# qubit to be used throughout the notebook
qubit = 0

### Collect the necessary channels
drive_chan = pulse.DriveChannel(qubit)
meas_chan = pulse.MeasureChannel(qubit)
acq_chan = pulse.AcquireChannel(qubit)

# Construct a measurement schedule and add it to an InstructionScheduleMap
meas_samples = 1200
meas_pulse = GaussianSquare(duration=meas_samples, amp=0.025, sigma=4, width=1150)
measure_sched = Play(meas_pulse, meas_chan) | Acquire(meas_samples, acq_chan, pulse.MemorySlot(qubit))

inst_map = pulse.InstructionScheduleMap()
inst_map.add('measure', [qubit], measure_sched)

# save the measurement/acquire pulse for later
measure = inst_map.get('measure', qubits=[qubit])
print(measure)
# Out:
# Schedule((0, Play(GaussianSquare(duration=1200, amp=(0.025+0j), sigma=4, width=1150), MeasureChannel(0))), (0, Acquire(1200, AcquireChannel(0), MemorySlot(0))), name="sched512")

# %% [markdown]
# ## Graded Exercise 1a: Rabi Schedule
#
# Add code to the method below in order to build a Rabi pulse schedule. A Rabi experiment consists of a drive pulse at the qubit frequency, followed by a measurement. A list of Rabis schedules will vary the drive amplitude each time. For a review of creating pulse schedules, see [Lab 6 notebook](lab6-drive-ham-rabi-ramsey.ipynb).

# %%
from qiskit.pulse import pulse_lib

def build_rabi_pulse_schedule(drive_duration, drive_amp, drive_sigma):
    ### create a Rabi schedule (already done)
    ### create a Gaussian Rabi pulse using pulse_lib
    ### play Rabi pulse on the Rabi schedule and return
    
    rabi_schedule = pulse.Schedule(name='rabi_experiment')
    
    ### WRITE YOUR CODE BETWEEN THESE LINES - START
    rabi_pulse = pulse_lib.gaussian(duration=drive_duration, amp=drive_amp, 
                                    sigma=drive_sigma, name=f"Rabi drive amplitude = {drive_amp}")
    
    rabi_schedule += Play(rabi_pulse, drive_chan)
    ### WRITE YOUR CODE BETWEEN THESE LINES - END
    
    # add measurement to rabi_schedule
    # << indicates time shift the beginning to the start of the schedule
    rabi_schedule += measure << rabi_schedule.duration
    return rabi_schedule

# %% [markdown]
# ### From the Rabi schedule of Exercise 1a, create a list of schedules for the experiment

# %%
# Gaussian pulse parameters, with varying amplitude
drive_duration = 128
num_rabi_points = 41
drive_amps = np.linspace(0, 0.9, num_rabi_points)
drive_sigma = 16

# now vary the amplitude for each drive amp
rabi_schedules = []
for drive_amp in drive_amps:
    rabi_schedules.append(build_rabi_pulse_schedule(drive_duration, drive_amp, drive_sigma))

# %%
rabi_schedules[-1].draw()

# %%
# assemble the schedules into a Qobj
from qiskit import assemble

rabi_qobj = assemble(**helper.get_params('rabi', globals()))
answer1a = rabi_qobj
print(answer1a)
# Out:
# Pulse Qobj: 56ff849c-8add-4342-97dd-1f6342478796:
# Config: {'meas_level': 1,
#  'meas_lo_freq': [inf],
#  'meas_return': 'avg',
#  'memory': False,
#  'memory_slot_size': 100,
#  'memory_slots': 1,
#  'parametric_pulses': [],
#  'pulse_library': [{'name': 'e5a00aa9991ac8a5ee3109844d84a55583bd20572ad3ffcd42792f3c36b183ad',
#                     'samples': array([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j])},
#                    {'name': 'bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a',
#                     'samples': array([1.78453696e-10+0.j, 7.99773979e-10+0.j, 3.36717422e-09+0.j, ...,
#        3.36717422e-09+0.j, 7.99773979e-10+0.j, 1.78453696e-10+0.j])},
#                    {'name': 'd29c4b58ee50d741f45dda4f611c4829525a0629cd01a17c901b817ab61ea578',
#                     'samples': array([1.00115307e-06+0.j, 3.38721465e-06+0.j, 6.38449409e-06+0.j,
#        1.01339125e-05+0.j, 1.48046768e-05+0.j, 2.05989027e-05+0.j,
#        2.77567462e-05+0.j, 3.65620420e-05+0.j, 4.73484313e-05+0.j,
#        6.05059446e-05+0.j, 7.64879780e-05+0.j, 9.58185802e-05+0.j,
#        1.19099932e-04+0.j, 1.47019868e-04+0.j, 1.80359267e-04+0.j,
#        2.19999065e-04+0.j, 2.66926656e-04+0.j, 3.22241368e-04+0.j,
#        3.87158673e-04+0.j, 4.63012782e-04+0.j, 5.51257213e-04+0.j,
#        6.53462934e-04+0.j, 7.71313658e-04+0.j, 9.06597871e-04+0.j,
#        1.06119721e-03+0.j, 1.23707085e-03+0.j, 1.43623551e-03+0.j,
#        1.66074105e-03+0.j, 1.91264130e-03+0.j, 2.19396024e-03+0.j,
#        2.50665367e-03+0.j, 2.85256660e-03+0.j, 3.23338676e-03+0.j,
#        3.65059496e-03+0.j, 4.10541298e-03+0.j, 4.59875009e-03+0.j,
#        5.13114913e-03+0.j, 5.70273377e-03+0.j, 6.31315800e-03+0.j,
#        6.96155970e-03+0.j, 7.64651967e-03+0.j, 8.36602776e-03+0.j,
#        9.11745775e-03+0.j, 9.89755224e-03+0.j, 1.07024192e-02+0.j,
#        1.15275407e-02+0.j, 1.23677959e-02+0.j, 1.32174968e-02+0.j,
#        1.40704390e-02+0.j, 1.49199667e-02+0.j, 1.57590498e-02+0.j,
#        1.65803750e-02+0.j, 1.73764461e-02+0.j, 1.81396953e-02+0.j,
#        1.88625993e-02+0.j, 1.95378023e-02+0.j, 2.01582384e-02+0.j,
#        2.07172547e-02+0.j, 2.12087292e-02+0.j, 2.16271829e-02+0.j,
#        2.19678803e-02+0.j, 2.22269198e-02+0.j, 2.24013069e-02+0.j,
#        2.24890127e-02+0.j, 2.24890127e-02+0.j, 2.24013069e-02+0.j,
#        2.22269198e-02+0.j, 2.19678803e-02+0.j, 2.16271829e-02+0.j,
#        2.12087292e-02+0.j, 2.07172547e-02+0.j, 2.01582384e-02+0.j,
#        1.95378023e-02+0.j, 1.88625993e-02+0.j, 1.81396953e-02+0.j,
#        1.73764461e-02+0.j, 1.65803750e-02+0.j, 1.57590498e-02+0.j,
#        1.49199667e-02+0.j, 1.40704390e-02+0.j, 1.32174968e-02+0.j,
#        1.23677959e-02+0.j, 1.15275407e-02+0.j, 1.07024192e-02+0.j,
#        9.89755224e-03+0.j, 9.11745775e-03+0.j, 8.36602776e-03+0.j,
#        7.64651967e-03+0.j, 6.96155970e-03+0.j, 6.31315800e-03+0.j,
#        5.70273377e-03+0.j, 5.13114913e-03+0.j, 4.59875009e-03+0.j,
#        4.10541298e-03+0.j, 3.65059496e-03+0.j, 3.23338676e-03+0.j,
#        2.85256660e-03+0.j, 2.50665367e-03+0.j, 2.19396024e-03+0.j,
#        1.91264130e-03+0.j, 1.66074105e-03+0.j, 1.43623551e-03+0.j,
#        1.23707085e-03+0.j, 1.06119721e-03+0.j, 9.06597871e-04+0.j,
#        7.71313658e-04+0.j, 6.53462934e-04+0.j, 5.51257213e-04+0.j,
#        4.63012782e-04+0.j, 3.87158673e-04+0.j, 3.22241368e-04+0.j,
#        2.66926656e-04+0.j, 2.19999065e-04+0.j, 1.80359267e-04+0.j,
#        1.47019868e-04+0.j, 1.19099932e-04+0.j, 9.58185802e-05+0.j,
#        7.64879780e-05+0.j, 6.05059446e-05+0.j, 4.73484313e-05+0.j,
#        3.65620420e-05+0.j, 2.77567462e-05+0.j, 2.05989027e-05+0.j,
#        1.48046768e-05+0.j, 1.01339125e-05+0.j, 6.38449409e-06+0.j,
#        3.38721465e-06+0.j, 1.00115307e-06+0.j])},
#                    {'name': '83833cc210b1d4c59348630cea5d8dec3025c7b0cc9a3fdfc243178250a7adec',
#                     'samples': array([2.00230614e-06+0.j, 6.77442931e-06+0.j, 1.27689882e-05+0.j,
#        2.02678251e-05+0.j, 2.96093536e-05+0.j, 4.11978054e-05+0.j,
#        5.55134924e-05+0.j, 7.31240839e-05+0.j, 9.46968626e-05+0.j,
#        1.21011889e-04+0.j, 1.52975956e-04+0.j, 1.91637160e-04+0.j,
#        2.38199863e-04+0.j, 2.94039737e-04+0.j, 3.60718534e-04+0.j,
#        4.39998129e-04+0.j, 5.33853312e-04+0.j, 6.44482735e-04+0.j,
#        7.74317346e-04+0.j, 9.26025564e-04+0.j, 1.10251443e-03+0.j,
#        1.30692587e-03+0.j, 1.54262732e-03+0.j, 1.81319574e-03+0.j,
#        2.12239443e-03+0.j, 2.47414169e-03+0.j, 2.87247102e-03+0.j,
#        3.32148211e-03+0.j, 3.82528260e-03+0.j, 4.38792047e-03+0.j,
#        5.01330734e-03+0.j, 5.70513319e-03+0.j, 6.46677351e-03+0.j,
#        7.30118991e-03+0.j, 8.21082597e-03+0.j, 9.19750018e-03+0.j,
#        1.02622983e-02+0.j, 1.14054675e-02+0.j, 1.26263160e-02+0.j,
#        1.39231194e-02+0.j, 1.52930393e-02+0.j, 1.67320555e-02+0.j,
#        1.82349155e-02+0.j, 1.97951045e-02+0.j, 2.14048383e-02+0.j,
#        2.30550815e-02+0.j, 2.47355918e-02+0.j, 2.64349935e-02+0.j,
#        2.81408780e-02+0.j, 2.98399334e-02+0.j, 3.15180997e-02+0.j,
#        3.31607500e-02+0.j, 3.47528923e-02+0.j, 3.62793905e-02+0.j,
#        3.77251987e-02+0.j, 3.90756046e-02+0.j, 4.03164768e-02+0.j,
#        4.14345093e-02+0.j, 4.24174585e-02+0.j, 4.32543657e-02+0.j,
#        4.39357607e-02+0.j, 4.44538395e-02+0.j, 4.48026138e-02+0.j,
#        4.49780253e-02+0.j, 4.49780253e-02+0.j, 4.48026138e-02+0.j,
#        4.44538395e-02+0.j, 4.39357607e-02+0.j, 4.32543657e-02+0.j,
#        4.24174585e-02+0.j, 4.14345093e-02+0.j, 4.03164768e-02+0.j,
#        3.90756046e-02+0.j, 3.77251987e-02+0.j, 3.62793905e-02+0.j,
#        3.47528923e-02+0.j, 3.31607500e-02+0.j, 3.15180997e-02+0.j,
#        2.98399334e-02+0.j, 2.81408780e-02+0.j, 2.64349935e-02+0.j,
#        2.47355918e-02+0.j, 2.30550815e-02+0.j, 2.14048383e-02+0.j,
#        1.97951045e-02+0.j, 1.82349155e-02+0.j, 1.67320555e-02+0.j,
#        1.52930393e-02+0.j, 1.39231194e-02+0.j, 1.26263160e-02+0.j,
#        1.14054675e-02+0.j, 1.02622983e-02+0.j, 9.19750018e-03+0.j,
#        8.21082597e-03+0.j, 7.30118991e-03+0.j, 6.46677351e-03+0.j,
#        5.70513319e-03+0.j, 5.01330734e-03+0.j, 4.38792047e-03+0.j,
#        3.82528260e-03+0.j, 3.32148211e-03+0.j, 2.87247102e-03+0.j,
#        2.47414169e-03+0.j, 2.12239443e-03+0.j, 1.81319574e-03+0.j,
#        1.54262732e-03+0.j, 1.30692587e-03+0.j, 1.10251443e-03+0.j,
#        9.26025564e-04+0.j, 7.74317346e-04+0.j, 6.44482735e-04+0.j,
#        5.33853312e-04+0.j, 4.39998129e-04+0.j, 3.60718534e-04+0.j,
#        2.94039737e-04+0.j, 2.38199863e-04+0.j, 1.91637160e-04+0.j,
#        1.52975956e-04+0.j, 1.21011889e-04+0.j, 9.46968626e-05+0.j,
#        7.31240839e-05+0.j, 5.55134924e-05+0.j, 4.11978054e-05+0.j,
#        2.96093536e-05+0.j, 2.02678251e-05+0.j, 1.27689882e-05+0.j,
#        6.77442931e-06+0.j, 2.00230614e-06+0.j])},
#                    {'name': 'e36898dd4bd900c403ac254e147ffcc2e2482ec5b1db6d40baa031d5c0e638a1',
#                     'samples': array([3.00345921e-06+0.j, 1.01616440e-05+0.j, 1.91534823e-05+0.j,
#        3.04017376e-05+0.j, 4.44140305e-05+0.j, 6.17967081e-05+0.j,
#        8.32702386e-05+0.j, 1.09686126e-04+0.j, 1.42045294e-04+0.j,
#        1.81517834e-04+0.j, 2.29463934e-04+0.j, 2.87455741e-04+0.j,
#        3.57299795e-04+0.j, 4.41059605e-04+0.j, 5.41077801e-04+0.j,
#        6.59997194e-04+0.j, 8.00779968e-04+0.j, 9.66724103e-04+0.j,
#        1.16147602e-03+0.j, 1.38903835e-03+0.j, 1.65377164e-03+0.j,
#        1.96038880e-03+0.j, 2.31394097e-03+0.j, 2.71979361e-03+0.j,
#        3.18359164e-03+0.j, 3.71121254e-03+0.j, 4.30870653e-03+0.j,
#        4.98222316e-03+0.j, 5.73792390e-03+0.j, 6.58188071e-03+0.j,
#        7.51996101e-03+0.j, 8.55769979e-03+0.j, 9.70016027e-03+0.j,
#        1.09517849e-02+0.j, 1.23162390e-02+0.j, 1.37962503e-02+0.j,
#        1.53934474e-02+0.j, 1.71082013e-02+0.j, 1.89394740e-02+0.j,
#        2.08846791e-02+0.j, 2.29395590e-02+0.j, 2.50980833e-02+0.j,
#        2.73523732e-02+0.j, 2.96926567e-02+0.j, 3.21072575e-02+0.j,
#        3.45826222e-02+0.j, 3.71033878e-02+0.j, 3.96524903e-02+0.j,
#        4.22113171e-02+0.j, 4.47599001e-02+0.j, 4.72771495e-02+0.j,
#        4.97411250e-02+0.j, 5.21293384e-02+0.j, 5.44190858e-02+0.j,
#        5.65877980e-02+0.j, 5.86134069e-02+0.j, 6.04747152e-02+0.j,
#        6.21517640e-02+0.j, 6.36261877e-02+0.j, 6.48815486e-02+0.j,
#        6.59036410e-02+0.j, 6.66807593e-02+0.j, 6.72039206e-02+0.j,
#        6.74670380e-02+0.j, 6.74670380e-02+0.j, 6.72039206e-02+0.j,
#        6.66807593e-02+0.j, 6.59036410e-02+0.j, 6.48815486e-02+0.j,
#        6.36261877e-02+0.j, 6.21517640e-02+0.j, 6.04747152e-02+0.j,
#        5.86134069e-02+0.j, 5.65877980e-02+0.j, 5.44190858e-02+0.j,
#        5.21293384e-02+0.j, 4.97411250e-02+0.j, 4.72771495e-02+0.j,
#        4.47599001e-02+0.j, 4.22113171e-02+0.j, 3.96524903e-02+0.j,
#        3.71033878e-02+0.j, 3.45826222e-02+0.j, 3.21072575e-02+0.j,
#        2.96926567e-02+0.j, 2.73523732e-02+0.j, 2.50980833e-02+0.j,
#        2.29395590e-02+0.j, 2.08846791e-02+0.j, 1.89394740e-02+0.j,
#        1.71082013e-02+0.j, 1.53934474e-02+0.j, 1.37962503e-02+0.j,
#        1.23162390e-02+0.j, 1.09517849e-02+0.j, 9.70016027e-03+0.j,
#        8.55769979e-03+0.j, 7.51996101e-03+0.j, 6.58188071e-03+0.j,
#        5.73792390e-03+0.j, 4.98222316e-03+0.j, 4.30870653e-03+0.j,
#        3.71121254e-03+0.j, 3.18359164e-03+0.j, 2.71979361e-03+0.j,
#        2.31394097e-03+0.j, 1.96038880e-03+0.j, 1.65377164e-03+0.j,
#        1.38903835e-03+0.j, 1.16147602e-03+0.j, 9.66724103e-04+0.j,
#        8.00779968e-04+0.j, 6.59997194e-04+0.j, 5.41077801e-04+0.j,
#        4.41059605e-04+0.j, 3.57299795e-04+0.j, 2.87455741e-04+0.j,
#        2.29463934e-04+0.j, 1.81517834e-04+0.j, 1.42045294e-04+0.j,
#        1.09686126e-04+0.j, 8.32702386e-05+0.j, 6.17967081e-05+0.j,
#        4.44140305e-05+0.j, 3.04017376e-05+0.j, 1.91534823e-05+0.j,
#        1.01616440e-05+0.j, 3.00345921e-06+0.j])},
#                    {'name': '73bd08a80d4915c737b1e2777cfabc47b95f8b33c8d5737eb011fed4a2016fa3',
#                     'samples': array([4.00461229e-06+0.j, 1.35488586e-05+0.j, 2.55379764e-05+0.j,
#        4.05356502e-05+0.j, 5.92187073e-05+0.j, 8.23956108e-05+0.j,
#        1.11026985e-04+0.j, 1.46248168e-04+0.j, 1.89393725e-04+0.j,
#        2.42023778e-04+0.j, 3.05951912e-04+0.j, 3.83274321e-04+0.j,
#        4.76399726e-04+0.j, 5.88079473e-04+0.j, 7.21437068e-04+0.j,
#        8.79996258e-04+0.j, 1.06770662e-03+0.j, 1.28896547e-03+0.j,
#        1.54863469e-03+0.j, 1.85205113e-03+0.j, 2.20502885e-03+0.j,
#        2.61385174e-03+0.j, 3.08525463e-03+0.j, 3.62639148e-03+0.j,
#        4.24478885e-03+0.j, 4.94828338e-03+0.j, 5.74494204e-03+0.j,
#        6.64296422e-03+0.j, 7.65056520e-03+0.j, 8.77584095e-03+0.j,
#        1.00266147e-02+0.j, 1.14102664e-02+0.j, 1.29335470e-02+0.j,
#        1.46023798e-02+0.j, 1.64216519e-02+0.j, 1.83950004e-02+0.j,
#        2.05245965e-02+0.j, 2.28109351e-02+0.j, 2.52526320e-02+0.j,
#        2.78462388e-02+0.j, 3.05860787e-02+0.j, 3.34641111e-02+0.j,
#        3.64698310e-02+0.j, 3.95902090e-02+0.j, 4.28096767e-02+0.j,
#        4.61101630e-02+0.j, 4.94711837e-02+0.j, 5.28699870e-02+0.j,
#        5.62817561e-02+0.j, 5.96798667e-02+0.j, 6.30361994e-02+0.j,
#        6.63214999e-02+0.j, 6.95057846e-02+0.j, 7.25587810e-02+0.j,
#        7.54503974e-02+0.j, 7.81512092e-02+0.j, 8.06329536e-02+0.j,
#        8.28690186e-02+0.j, 8.48349170e-02+0.j, 8.65087315e-02+0.j,
#        8.78715214e-02+0.j, 8.89076791e-02+0.j, 8.96052275e-02+0.j,
#        8.99560507e-02+0.j, 8.99560507e-02+0.j, 8.96052275e-02+0.j,
#        8.89076791e-02+0.j, 8.78715214e-02+0.j, 8.65087315e-02+0.j,
#        8.48349170e-02+0.j, 8.28690186e-02+0.j, 8.06329536e-02+0.j,
#        7.81512092e-02+0.j, 7.54503974e-02+0.j, 7.25587810e-02+0.j,
#        6.95057846e-02+0.j, 6.63214999e-02+0.j, 6.30361994e-02+0.j,
#        5.96798667e-02+0.j, 5.62817561e-02+0.j, 5.28699870e-02+0.j,
#        4.94711837e-02+0.j, 4.61101630e-02+0.j, 4.28096767e-02+0.j,
#        3.95902090e-02+0.j, 3.64698310e-02+0.j, 3.34641111e-02+0.j,
#        3.05860787e-02+0.j, 2.78462388e-02+0.j, 2.52526320e-02+0.j,
#        2.28109351e-02+0.j, 2.05245965e-02+0.j, 1.83950004e-02+0.j,
#        1.64216519e-02+0.j, 1.46023798e-02+0.j, 1.29335470e-02+0.j,
#        1.14102664e-02+0.j, 1.00266147e-02+0.j, 8.77584095e-03+0.j,
#        7.65056520e-03+0.j, 6.64296422e-03+0.j, 5.74494204e-03+0.j,
#        4.94828338e-03+0.j, 4.24478885e-03+0.j, 3.62639148e-03+0.j,
#        3.08525463e-03+0.j, 2.61385174e-03+0.j, 2.20502885e-03+0.j,
#        1.85205113e-03+0.j, 1.54863469e-03+0.j, 1.28896547e-03+0.j,
#        1.06770662e-03+0.j, 8.79996258e-04+0.j, 7.21437068e-04+0.j,
#        5.88079473e-04+0.j, 4.76399726e-04+0.j, 3.83274321e-04+0.j,
#        3.05951912e-04+0.j, 2.42023778e-04+0.j, 1.89393725e-04+0.j,
#        1.46248168e-04+0.j, 1.11026985e-04+0.j, 8.23956108e-05+0.j,
#        5.92187073e-05+0.j, 4.05356502e-05+0.j, 2.55379764e-05+0.j,
#        1.35488586e-05+0.j, 4.00461229e-06+0.j])},
#                    {'name': '250d72bae3d89db07ef44394a81b3f500347f738283635fb098820ad4893e8ea',
#                     'samples': array([5.00576536e-06+0.j, 1.69360733e-05+0.j, 3.19224704e-05+0.j,
#        5.06695627e-05+0.j, 7.40233841e-05+0.j, 1.02994513e-04+0.j,
#        1.38783731e-04+0.j, 1.82810210e-04+0.j, 2.36742156e-04+0.j,
#        3.02529723e-04+0.j, 3.82439890e-04+0.j, 4.79092901e-04+0.j,
#        5.95499658e-04+0.j, 7.35099342e-04+0.j, 9.01796335e-04+0.j,
#        1.09999532e-03+0.j, 1.33463328e-03+0.j, 1.61120684e-03+0.j,
#        1.93579336e-03+0.j, 2.31506391e-03+0.j, 2.75628606e-03+0.j,
#        3.26731467e-03+0.j, 3.85656829e-03+0.j, 4.53298935e-03+0.j,
#        5.30598606e-03+0.j, 6.18535423e-03+0.j, 7.18117755e-03+0.j,
#        8.30370527e-03+0.j, 9.56320650e-03+0.j, 1.09698012e-02+0.j,
#        1.25332683e-02+0.j, 1.42628330e-02+0.j, 1.61669338e-02+0.j,
#        1.82529748e-02+0.j, 2.05270649e-02+0.j, 2.29937504e-02+0.j,
#        2.56557457e-02+0.j, 2.85136689e-02+0.j, 3.15657900e-02+0.j,
#        3.48077985e-02+0.j, 3.82325983e-02+0.j, 4.18301388e-02+0.j,
#        4.55872887e-02+0.j, 4.94877612e-02+0.j, 5.35120958e-02+0.j,
#        5.76377037e-02+0.j, 6.18389796e-02+0.j, 6.60874838e-02+0.j,
#        7.03521951e-02+0.j, 7.45998334e-02+0.j, 7.87952492e-02+0.j,
#        8.29018749e-02+0.j, 8.68822307e-02+0.j, 9.06984763e-02+0.j,
#        9.43129967e-02+0.j, 9.76890115e-02+0.j, 1.00791192e-01+0.j,
#        1.03586273e-01+0.j, 1.06043646e-01+0.j, 1.08135914e-01+0.j,
#        1.09839402e-01+0.j, 1.11134599e-01+0.j, 1.12006534e-01+0.j,
#        1.12445063e-01+0.j, 1.12445063e-01+0.j, 1.12006534e-01+0.j,
#        1.11134599e-01+0.j, 1.09839402e-01+0.j, 1.08135914e-01+0.j,
#        1.06043646e-01+0.j, 1.03586273e-01+0.j, 1.00791192e-01+0.j,
#        9.76890115e-02+0.j, 9.43129967e-02+0.j, 9.06984763e-02+0.j,
#        8.68822307e-02+0.j, 8.29018749e-02+0.j, 7.87952492e-02+0.j,
#        7.45998334e-02+0.j, 7.03521951e-02+0.j, 6.60874838e-02+0.j,
#        6.18389796e-02+0.j, 5.76377037e-02+0.j, 5.35120958e-02+0.j,
#        4.94877612e-02+0.j, 4.55872887e-02+0.j, 4.18301388e-02+0.j,
#        3.82325983e-02+0.j, 3.48077985e-02+0.j, 3.15657900e-02+0.j,
#        2.85136689e-02+0.j, 2.56557457e-02+0.j, 2.29937504e-02+0.j,
#        2.05270649e-02+0.j, 1.82529748e-02+0.j, 1.61669338e-02+0.j,
#        1.42628330e-02+0.j, 1.25332683e-02+0.j, 1.09698012e-02+0.j,
#        9.56320650e-03+0.j, 8.30370527e-03+0.j, 7.18117755e-03+0.j,
#        6.18535423e-03+0.j, 5.30598606e-03+0.j, 4.53298935e-03+0.j,
#        3.85656829e-03+0.j, 3.26731467e-03+0.j, 2.75628606e-03+0.j,
#        2.31506391e-03+0.j, 1.93579336e-03+0.j, 1.61120684e-03+0.j,
#        1.33463328e-03+0.j, 1.09999532e-03+0.j, 9.01796335e-04+0.j,
#        7.35099342e-04+0.j, 5.95499658e-04+0.j, 4.79092901e-04+0.j,
#        3.82439890e-04+0.j, 3.02529723e-04+0.j, 2.36742156e-04+0.j,
#        1.82810210e-04+0.j, 1.38783731e-04+0.j, 1.02994513e-04+0.j,
#        7.40233841e-05+0.j, 5.06695627e-05+0.j, 3.19224704e-05+0.j,
#        1.69360733e-05+0.j, 5.00576536e-06+0.j])},
#                    {'name': '292a2cd8e6a277c901b8fa5a84cbfc30d84efccee3482bf1c4f9e31756bd8e56',
#                     'samples': array([6.00691843e-06+0.j, 2.03232879e-05+0.j, 3.83069645e-05+0.j,
#        6.08034753e-05+0.j, 8.88280609e-05+0.j, 1.23593416e-04+0.j,
#        1.66540477e-04+0.j, 2.19372252e-04+0.j, 2.84090588e-04+0.j,
#        3.63035667e-04+0.j, 4.58927868e-04+0.j, 5.74911481e-04+0.j,
#        7.14599589e-04+0.j, 8.82119210e-04+0.j, 1.08215560e-03+0.j,
#        1.31999439e-03+0.j, 1.60155994e-03+0.j, 1.93344821e-03+0.j,
#        2.32295204e-03+0.j, 2.77807669e-03+0.j, 3.30754328e-03+0.j,
#        3.92077760e-03+0.j, 4.62788195e-03+0.j, 5.43958722e-03+0.j,
#        6.36718328e-03+0.j, 7.42242507e-03+0.j, 8.61741306e-03+0.j,
#        9.96444633e-03+0.j, 1.14758478e-02+0.j, 1.31637614e-02+0.j,
#        1.50399220e-02+0.j, 1.71153996e-02+0.j, 1.94003205e-02+0.j,
#        2.19035697e-02+0.j, 2.46324779e-02+0.j, 2.75925005e-02+0.j,
#        3.07868948e-02+0.j, 3.42164026e-02+0.j, 3.78789480e-02+0.j,
#        4.17693582e-02+0.j, 4.58791180e-02+0.j, 5.01961666e-02+0.j,
#        5.47047465e-02+0.j, 5.93853134e-02+0.j, 6.42145150e-02+0.j,
#        6.91652445e-02+0.j, 7.42067755e-02+0.j, 7.93049806e-02+0.j,
#        8.44226341e-02+0.j, 8.95198001e-02+0.j, 9.45542991e-02+0.j,
#        9.94822499e-02+0.j, 1.04258677e-01+0.j, 1.08838172e-01+0.j,
#        1.13175596e-01+0.j, 1.17226814e-01+0.j, 1.20949430e-01+0.j,
#        1.24303528e-01+0.j, 1.27252375e-01+0.j, 1.29763097e-01+0.j,
#        1.31807282e-01+0.j, 1.33361519e-01+0.j, 1.34407841e-01+0.j,
#        1.34934076e-01+0.j, 1.34934076e-01+0.j, 1.34407841e-01+0.j,
#        1.33361519e-01+0.j, 1.31807282e-01+0.j, 1.29763097e-01+0.j,
#        1.27252375e-01+0.j, 1.24303528e-01+0.j, 1.20949430e-01+0.j,
#        1.17226814e-01+0.j, 1.13175596e-01+0.j, 1.08838172e-01+0.j,
#        1.04258677e-01+0.j, 9.94822499e-02+0.j, 9.45542991e-02+0.j,
#        8.95198001e-02+0.j, 8.44226341e-02+0.j, 7.93049806e-02+0.j,
#        7.42067755e-02+0.j, 6.91652445e-02+0.j, 6.42145150e-02+0.j,
#        5.93853134e-02+0.j, 5.47047465e-02+0.j, 5.01961666e-02+0.j,
#        4.58791180e-02+0.j, 4.17693582e-02+0.j, 3.78789480e-02+0.j,
#        3.42164026e-02+0.j, 3.07868948e-02+0.j, 2.75925005e-02+0.j,
#        2.46324779e-02+0.j, 2.19035697e-02+0.j, 1.94003205e-02+0.j,
#        1.71153996e-02+0.j, 1.50399220e-02+0.j, 1.31637614e-02+0.j,
#        1.14758478e-02+0.j, 9.96444633e-03+0.j, 8.61741306e-03+0.j,
#        7.42242507e-03+0.j, 6.36718328e-03+0.j, 5.43958722e-03+0.j,
#        4.62788195e-03+0.j, 3.92077760e-03+0.j, 3.30754328e-03+0.j,
#        2.77807669e-03+0.j, 2.32295204e-03+0.j, 1.93344821e-03+0.j,
#        1.60155994e-03+0.j, 1.31999439e-03+0.j, 1.08215560e-03+0.j,
#        8.82119210e-04+0.j, 7.14599589e-04+0.j, 5.74911481e-04+0.j,
#        4.58927868e-04+0.j, 3.63035667e-04+0.j, 2.84090588e-04+0.j,
#        2.19372252e-04+0.j, 1.66540477e-04+0.j, 1.23593416e-04+0.j,
#        8.88280609e-05+0.j, 6.08034753e-05+0.j, 3.83069645e-05+0.j,
#        2.03232879e-05+0.j, 6.00691843e-06+0.j])},
#                    {'name': 'ded75b2df18cd745c5a951e575b95c32d187a5b24f9746f5a1c1d832a0548822',
#                     'samples': array([7.00807150e-06+0.j, 2.37105026e-05+0.j, 4.46914586e-05+0.j,
#        7.09373878e-05+0.j, 1.03632738e-04+0.j, 1.44192319e-04+0.j,
#        1.94297223e-04+0.j, 2.55934294e-04+0.j, 3.31439019e-04+0.j,
#        4.23541612e-04+0.j, 5.35415846e-04+0.j, 6.70730062e-04+0.j,
#        8.33699521e-04+0.j, 1.02913908e-03+0.j, 1.26251487e-03+0.j,
#        1.53999345e-03+0.j, 1.86848659e-03+0.j, 2.25568957e-03+0.j,
#        2.71011071e-03+0.j, 3.24108947e-03+0.j, 3.85880049e-03+0.j,
#        4.57424054e-03+0.j, 5.39919560e-03+0.j, 6.34618509e-03+0.j,
#        7.42838049e-03+0.j, 8.65949592e-03+0.j, 1.00536486e-02+0.j,
#        1.16251874e-02+0.j, 1.33884891e-02+0.j, 1.53577217e-02+0.j,
#        1.75465757e-02+0.j, 1.99679662e-02+0.j, 2.26337073e-02+0.j,
#        2.55541647e-02+0.j, 2.87378909e-02+0.j, 3.21912506e-02+0.j,
#        3.59180439e-02+0.j, 3.99191364e-02+0.j, 4.41921060e-02+0.j,
#        4.87309179e-02+0.j, 5.35256377e-02+0.j, 5.85621943e-02+0.j,
#        6.38222042e-02+0.j, 6.92828657e-02+0.j, 7.49169342e-02+0.j,
#        8.06927852e-02+0.j, 8.65745714e-02+0.j, 9.25224773e-02+0.j,
#        9.84930732e-02+0.j, 1.04439767e-01+0.j, 1.10313349e-01+0.j,
#        1.16062625e-01+0.j, 1.21635123e-01+0.j, 1.26977867e-01+0.j,
#        1.32038195e-01+0.j, 1.36764616e-01+0.j, 1.41107669e-01+0.j,
#        1.45020783e-01+0.j, 1.48461105e-01+0.j, 1.51390280e-01+0.j,
#        1.53775162e-01+0.j, 1.55588438e-01+0.j, 1.56809148e-01+0.j,
#        1.57423089e-01+0.j, 1.57423089e-01+0.j, 1.56809148e-01+0.j,
#        1.55588438e-01+0.j, 1.53775162e-01+0.j, 1.51390280e-01+0.j,
#        1.48461105e-01+0.j, 1.45020783e-01+0.j, 1.41107669e-01+0.j,
#        1.36764616e-01+0.j, 1.32038195e-01+0.j, 1.26977867e-01+0.j,
#        1.21635123e-01+0.j, 1.16062625e-01+0.j, 1.10313349e-01+0.j,
#        1.04439767e-01+0.j, 9.84930732e-02+0.j, 9.25224773e-02+0.j,
#        8.65745714e-02+0.j, 8.06927852e-02+0.j, 7.49169342e-02+0.j,
#        6.92828657e-02+0.j, 6.38222042e-02+0.j, 5.85621943e-02+0.j,
#        5.35256377e-02+0.j, 4.87309179e-02+0.j, 4.41921060e-02+0.j,
#        3.99191364e-02+0.j, 3.59180439e-02+0.j, 3.21912506e-02+0.j,
#        2.87378909e-02+0.j, 2.55541647e-02+0.j, 2.26337073e-02+0.j,
#        1.99679662e-02+0.j, 1.75465757e-02+0.j, 1.53577217e-02+0.j,
#        1.33884891e-02+0.j, 1.16251874e-02+0.j, 1.00536486e-02+0.j,
#        8.65949592e-03+0.j, 7.42838049e-03+0.j, 6.34618509e-03+0.j,
#        5.39919560e-03+0.j, 4.57424054e-03+0.j, 3.85880049e-03+0.j,
#        3.24108947e-03+0.j, 2.71011071e-03+0.j, 2.25568957e-03+0.j,
#        1.86848659e-03+0.j, 1.53999345e-03+0.j, 1.26251487e-03+0.j,
#        1.02913908e-03+0.j, 8.33699521e-04+0.j, 6.70730062e-04+0.j,
#        5.35415846e-04+0.j, 4.23541612e-04+0.j, 3.31439019e-04+0.j,
#        2.55934294e-04+0.j, 1.94297223e-04+0.j, 1.44192319e-04+0.j,
#        1.03632738e-04+0.j, 7.09373878e-05+0.j, 4.46914586e-05+0.j,
#        2.37105026e-05+0.j, 7.00807150e-06+0.j])},
#                    {'name': '6b67e1514bbd671d7f1a0dbbabfafee9e2aab013d22f064151153577ca09dab9',
#                     'samples': array([8.00922457e-06+0.j, 2.70977172e-05+0.j, 5.10759527e-05+0.j,
#        8.10713004e-05+0.j, 1.18437415e-04+0.j, 1.64791222e-04+0.j,
#        2.22053970e-04+0.j, 2.92496336e-04+0.j, 3.78787450e-04+0.j,
#        4.84047556e-04+0.j, 6.11903824e-04+0.j, 7.66548642e-04+0.j,
#        9.52799452e-04+0.j, 1.17615895e-03+0.j, 1.44287414e-03+0.j,
#        1.75999252e-03+0.j, 2.13541325e-03+0.j, 2.57793094e-03+0.j,
#        3.09726938e-03+0.j, 3.70410225e-03+0.j, 4.41005770e-03+0.j,
#        5.22770347e-03+0.j, 6.17050926e-03+0.j, 7.25278296e-03+0.j,
#        8.48957770e-03+0.j, 9.89656676e-03+0.j, 1.14898841e-02+0.j,
#        1.32859284e-02+0.j, 1.53011304e-02+0.j, 1.75516819e-02+0.j,
#        2.00532294e-02+0.j, 2.28205328e-02+0.j, 2.58670941e-02+0.j,
#        2.92047596e-02+0.j, 3.28433039e-02+0.j, 3.67900007e-02+0.j,
#        4.10491931e-02+0.j, 4.56218702e-02+0.j, 5.05052640e-02+0.j,
#        5.56924776e-02+0.j, 6.11721573e-02+0.j, 6.69282221e-02+0.j,
#        7.29396620e-02+0.j, 7.91804179e-02+0.j, 8.56193533e-02+0.j,
#        9.22203260e-02+0.j, 9.89423674e-02+0.j, 1.05739974e-01+0.j,
#        1.12563512e-01+0.j, 1.19359733e-01+0.j, 1.26072399e-01+0.j,
#        1.32643000e-01+0.j, 1.39011569e-01+0.j, 1.45117562e-01+0.j,
#        1.50900795e-01+0.j, 1.56302418e-01+0.j, 1.61265907e-01+0.j,
#        1.65738037e-01+0.j, 1.69669834e-01+0.j, 1.73017463e-01+0.j,
#        1.75743043e-01+0.j, 1.77815358e-01+0.j, 1.79210455e-01+0.j,
#        1.79912101e-01+0.j, 1.79912101e-01+0.j, 1.79210455e-01+0.j,
#        1.77815358e-01+0.j, 1.75743043e-01+0.j, 1.73017463e-01+0.j,
#        1.69669834e-01+0.j, 1.65738037e-01+0.j, 1.61265907e-01+0.j,
#        1.56302418e-01+0.j, 1.50900795e-01+0.j, 1.45117562e-01+0.j,
#        1.39011569e-01+0.j, 1.32643000e-01+0.j, 1.26072399e-01+0.j,
#        1.19359733e-01+0.j, 1.12563512e-01+0.j, 1.05739974e-01+0.j,
#        9.89423674e-02+0.j, 9.22203260e-02+0.j, 8.56193533e-02+0.j,
#        7.91804179e-02+0.j, 7.29396620e-02+0.j, 6.69282221e-02+0.j,
#        6.11721573e-02+0.j, 5.56924776e-02+0.j, 5.05052640e-02+0.j,
#        4.56218702e-02+0.j, 4.10491931e-02+0.j, 3.67900007e-02+0.j,
#        3.28433039e-02+0.j, 2.92047596e-02+0.j, 2.58670941e-02+0.j,
#        2.28205328e-02+0.j, 2.00532294e-02+0.j, 1.75516819e-02+0.j,
#        1.53011304e-02+0.j, 1.32859284e-02+0.j, 1.14898841e-02+0.j,
#        9.89656676e-03+0.j, 8.48957770e-03+0.j, 7.25278296e-03+0.j,
#        6.17050926e-03+0.j, 5.22770347e-03+0.j, 4.41005770e-03+0.j,
#        3.70410225e-03+0.j, 3.09726938e-03+0.j, 2.57793094e-03+0.j,
#        2.13541325e-03+0.j, 1.75999252e-03+0.j, 1.44287414e-03+0.j,
#        1.17615895e-03+0.j, 9.52799452e-04+0.j, 7.66548642e-04+0.j,
#        6.11903824e-04+0.j, 4.84047556e-04+0.j, 3.78787450e-04+0.j,
#        2.92496336e-04+0.j, 2.22053970e-04+0.j, 1.64791222e-04+0.j,
#        1.18437415e-04+0.j, 8.10713004e-05+0.j, 5.10759527e-05+0.j,
#        2.70977172e-05+0.j, 8.00922457e-06+0.j])},
#                    {'name': 'fae8fe9315f837a9494eca3c9f2cb06e8adfc2dd96e020a655fba0c5ac8e19e3',
#                     'samples': array([9.01037764e-06+0.j, 3.04849319e-05+0.j, 5.74604468e-05+0.j,
#        9.12052129e-05+0.j, 1.33242091e-04+0.j, 1.85390124e-04+0.j,
#        2.49810716e-04+0.j, 3.29058378e-04+0.j, 4.26135882e-04+0.j,
#        5.44553501e-04+0.j, 6.88391802e-04+0.j, 8.62367222e-04+0.j,
#        1.07189938e-03+0.j, 1.32317881e-03+0.j, 1.62323340e-03+0.j,
#        1.97999158e-03+0.j, 2.40233990e-03+0.j, 2.90017231e-03+0.j,
#        3.48442806e-03+0.j, 4.16711504e-03+0.j, 4.96131491e-03+0.j,
#        5.88116641e-03+0.j, 6.94182292e-03+0.j, 8.15938083e-03+0.j,
#        9.55077491e-03+0.j, 1.11336376e-02+0.j, 1.29261196e-02+0.j,
#        1.49466695e-02+0.j, 1.72137717e-02+0.j, 1.97456421e-02+0.j,
#        2.25598830e-02+0.j, 2.56730994e-02+0.j, 2.91004808e-02+0.j,
#        3.28553546e-02+0.j, 3.69487169e-02+0.j, 4.13887508e-02+0.j,
#        4.61803422e-02+0.j, 5.13246039e-02+0.j, 5.68184220e-02+0.j,
#        6.26540373e-02+0.j, 6.88186770e-02+0.j, 7.52942499e-02+0.j,
#        8.20571197e-02+0.j, 8.90779702e-02+0.j, 9.63217725e-02+0.j,
#        1.03747867e-01+0.j, 1.11310163e-01+0.j, 1.18957471e-01+0.j,
#        1.26633951e-01+0.j, 1.34279700e-01+0.j, 1.41831449e-01+0.j,
#        1.49223375e-01+0.j, 1.56388015e-01+0.j, 1.63257257e-01+0.j,
#        1.69763394e-01+0.j, 1.75840221e-01+0.j, 1.81424146e-01+0.j,
#        1.86455292e-01+0.j, 1.90878563e-01+0.j, 1.94644646e-01+0.j,
#        1.97710923e-01+0.j, 2.00042278e-01+0.j, 2.01611762e-01+0.j,
#        2.02401114e-01+0.j, 2.02401114e-01+0.j, 2.01611762e-01+0.j,
#        2.00042278e-01+0.j, 1.97710923e-01+0.j, 1.94644646e-01+0.j,
#        1.90878563e-01+0.j, 1.86455292e-01+0.j, 1.81424146e-01+0.j,
#        1.75840221e-01+0.j, 1.69763394e-01+0.j, 1.63257257e-01+0.j,
#        1.56388015e-01+0.j, 1.49223375e-01+0.j, 1.41831449e-01+0.j,
#        1.34279700e-01+0.j, 1.26633951e-01+0.j, 1.18957471e-01+0.j,
#        1.11310163e-01+0.j, 1.03747867e-01+0.j, 9.63217725e-02+0.j,
#        8.90779702e-02+0.j, 8.20571197e-02+0.j, 7.52942499e-02+0.j,
#        6.88186770e-02+0.j, 6.26540373e-02+0.j, 5.68184220e-02+0.j,
#        5.13246039e-02+0.j, 4.61803422e-02+0.j, 4.13887508e-02+0.j,
#        3.69487169e-02+0.j, 3.28553546e-02+0.j, 2.91004808e-02+0.j,
#        2.56730994e-02+0.j, 2.25598830e-02+0.j, 1.97456421e-02+0.j,
#        1.72137717e-02+0.j, 1.49466695e-02+0.j, 1.29261196e-02+0.j,
#        1.11336376e-02+0.j, 9.55077491e-03+0.j, 8.15938083e-03+0.j,
#        6.94182292e-03+0.j, 5.88116641e-03+0.j, 4.96131491e-03+0.j,
#        4.16711504e-03+0.j, 3.48442806e-03+0.j, 2.90017231e-03+0.j,
#        2.40233990e-03+0.j, 1.97999158e-03+0.j, 1.62323340e-03+0.j,
#        1.32317881e-03+0.j, 1.07189938e-03+0.j, 8.62367222e-04+0.j,
#        6.88391802e-04+0.j, 5.44553501e-04+0.j, 4.26135882e-04+0.j,
#        3.29058378e-04+0.j, 2.49810716e-04+0.j, 1.85390124e-04+0.j,
#        1.33242091e-04+0.j, 9.12052129e-05+0.j, 5.74604468e-05+0.j,
#        3.04849319e-05+0.j, 9.01037764e-06+0.j])},
#                    {'name': '3ff257d49fe236e3e0ba5a0a70cb98fecb1afd45df41b1c089b6e695cb6d985c',
#                     'samples': array([1.00115307e-05+0.j, 3.38721465e-05+0.j, 6.38449409e-05+0.j,
#        1.01339125e-04+0.j, 1.48046768e-04+0.j, 2.05989027e-04+0.j,
#        2.77567462e-04+0.j, 3.65620420e-04+0.j, 4.73484313e-04+0.j,
#        6.05059446e-04+0.j, 7.64879780e-04+0.j, 9.58185802e-04+0.j,
#        1.19099932e-03+0.j, 1.47019868e-03+0.j, 1.80359267e-03+0.j,
#        2.19999065e-03+0.j, 2.66926656e-03+0.j, 3.22241368e-03+0.j,
#        3.87158673e-03+0.j, 4.63012782e-03+0.j, 5.51257213e-03+0.j,
#        6.53462934e-03+0.j, 7.71313658e-03+0.j, 9.06597871e-03+0.j,
#        1.06119721e-02+0.j, 1.23707085e-02+0.j, 1.43623551e-02+0.j,
#        1.66074105e-02+0.j, 1.91264130e-02+0.j, 2.19396024e-02+0.j,
#        2.50665367e-02+0.j, 2.85256660e-02+0.j, 3.23338676e-02+0.j,
#        3.65059496e-02+0.j, 4.10541298e-02+0.j, 4.59875009e-02+0.j,
#        5.13114913e-02+0.j, 5.70273377e-02+0.j, 6.31315800e-02+0.j,
#        6.96155970e-02+0.j, 7.64651967e-02+0.j, 8.36602776e-02+0.j,
#        9.11745775e-02+0.j, 9.89755224e-02+0.j, 1.07024192e-01+0.j,
#        1.15275407e-01+0.j, 1.23677959e-01+0.j, 1.32174968e-01+0.j,
#        1.40704390e-01+0.j, 1.49199667e-01+0.j, 1.57590498e-01+0.j,
#        1.65803750e-01+0.j, 1.73764461e-01+0.j, 1.81396953e-01+0.j,
#        1.88625993e-01+0.j, 1.95378023e-01+0.j, 2.01582384e-01+0.j,
#        2.07172547e-01+0.j, 2.12087292e-01+0.j, 2.16271829e-01+0.j,
#        2.19678803e-01+0.j, 2.22269198e-01+0.j, 2.24013069e-01+0.j,
#        2.24890127e-01+0.j, 2.24890127e-01+0.j, 2.24013069e-01+0.j,
#        2.22269198e-01+0.j, 2.19678803e-01+0.j, 2.16271829e-01+0.j,
#        2.12087292e-01+0.j, 2.07172547e-01+0.j, 2.01582384e-01+0.j,
#        1.95378023e-01+0.j, 1.88625993e-01+0.j, 1.81396953e-01+0.j,
#        1.73764461e-01+0.j, 1.65803750e-01+0.j, 1.57590498e-01+0.j,
#        1.49199667e-01+0.j, 1.40704390e-01+0.j, 1.32174968e-01+0.j,
#        1.23677959e-01+0.j, 1.15275407e-01+0.j, 1.07024192e-01+0.j,
#        9.89755224e-02+0.j, 9.11745775e-02+0.j, 8.36602776e-02+0.j,
#        7.64651967e-02+0.j, 6.96155970e-02+0.j, 6.31315800e-02+0.j,
#        5.70273377e-02+0.j, 5.13114913e-02+0.j, 4.59875009e-02+0.j,
#        4.10541298e-02+0.j, 3.65059496e-02+0.j, 3.23338676e-02+0.j,
#        2.85256660e-02+0.j, 2.50665367e-02+0.j, 2.19396024e-02+0.j,
#        1.91264130e-02+0.j, 1.66074105e-02+0.j, 1.43623551e-02+0.j,
#        1.23707085e-02+0.j, 1.06119721e-02+0.j, 9.06597871e-03+0.j,
#        7.71313658e-03+0.j, 6.53462934e-03+0.j, 5.51257213e-03+0.j,
#        4.63012782e-03+0.j, 3.87158673e-03+0.j, 3.22241368e-03+0.j,
#        2.66926656e-03+0.j, 2.19999065e-03+0.j, 1.80359267e-03+0.j,
#        1.47019868e-03+0.j, 1.19099932e-03+0.j, 9.58185802e-04+0.j,
#        7.64879780e-04+0.j, 6.05059446e-04+0.j, 4.73484313e-04+0.j,
#        3.65620420e-04+0.j, 2.77567462e-04+0.j, 2.05989027e-04+0.j,
#        1.48046768e-04+0.j, 1.01339125e-04+0.j, 6.38449409e-05+0.j,
#        3.38721465e-05+0.j, 1.00115307e-05+0.j])},
#                    {'name': '36aa9699f197035fbc9df2f5243ee24d8017c37a517010a139f29837b6b6cfb9',
#                     'samples': array([1.10126838e-05+0.j, 3.72593612e-05+0.j, 7.02294350e-05+0.j,
#        1.11473038e-04+0.j, 1.62851445e-04+0.j, 2.26587930e-04+0.j,
#        3.05324208e-04+0.j, 4.02182462e-04+0.j, 5.20832744e-04+0.j,
#        6.65565390e-04+0.j, 8.41367758e-04+0.j, 1.05400438e-03+0.j,
#        1.31009925e-03+0.j, 1.61721855e-03+0.j, 1.98395194e-03+0.j,
#        2.41998971e-03+0.j, 2.93619322e-03+0.j, 3.54465505e-03+0.j,
#        4.25874540e-03+0.j, 5.09314060e-03+0.j, 6.06382934e-03+0.j,
#        7.18809228e-03+0.j, 8.48445023e-03+0.j, 9.97257658e-03+0.j,
#        1.16731693e-02+0.j, 1.36077793e-02+0.j, 1.57985906e-02+0.j,
#        1.82681516e-02+0.j, 2.10390543e-02+0.j, 2.41335626e-02+0.j,
#        2.75731904e-02+0.j, 3.13782326e-02+0.j, 3.55672543e-02+0.j,
#        4.01565445e-02+0.j, 4.51595428e-02+0.j, 5.05862510e-02+0.j,
#        5.64426405e-02+0.j, 6.27300715e-02+0.j, 6.94447380e-02+0.j,
#        7.65771567e-02+0.j, 8.41117163e-02+0.j, 9.20263054e-02+0.j,
#        1.00292035e-01+0.j, 1.08873075e-01+0.j, 1.17726611e-01+0.j,
#        1.26802948e-01+0.j, 1.36045755e-01+0.j, 1.45392464e-01+0.j,
#        1.54774829e-01+0.j, 1.64119634e-01+0.j, 1.73349548e-01+0.j,
#        1.82384125e-01+0.j, 1.91140908e-01+0.j, 1.99536648e-01+0.j,
#        2.07488593e-01+0.j, 2.14915825e-01+0.j, 2.21740622e-01+0.j,
#        2.27889801e-01+0.j, 2.33296022e-01+0.j, 2.37899012e-01+0.j,
#        2.41646684e-01+0.j, 2.44496117e-01+0.j, 2.46414376e-01+0.j,
#        2.47379139e-01+0.j, 2.47379139e-01+0.j, 2.46414376e-01+0.j,
#        2.44496117e-01+0.j, 2.41646684e-01+0.j, 2.37899012e-01+0.j,
#        2.33296022e-01+0.j, 2.27889801e-01+0.j, 2.21740622e-01+0.j,
#        2.14915825e-01+0.j, 2.07488593e-01+0.j, 1.99536648e-01+0.j,
#        1.91140908e-01+0.j, 1.82384125e-01+0.j, 1.73349548e-01+0.j,
#        1.64119634e-01+0.j, 1.54774829e-01+0.j, 1.45392464e-01+0.j,
#        1.36045755e-01+0.j, 1.26802948e-01+0.j, 1.17726611e-01+0.j,
#        1.08873075e-01+0.j, 1.00292035e-01+0.j, 9.20263054e-02+0.j,
#        8.41117163e-02+0.j, 7.65771567e-02+0.j, 6.94447380e-02+0.j,
#        6.27300715e-02+0.j, 5.64426405e-02+0.j, 5.05862510e-02+0.j,
#        4.51595428e-02+0.j, 4.01565445e-02+0.j, 3.55672543e-02+0.j,
#        3.13782326e-02+0.j, 2.75731904e-02+0.j, 2.41335626e-02+0.j,
#        2.10390543e-02+0.j, 1.82681516e-02+0.j, 1.57985906e-02+0.j,
#        1.36077793e-02+0.j, 1.16731693e-02+0.j, 9.97257658e-03+0.j,
#        8.48445023e-03+0.j, 7.18809228e-03+0.j, 6.06382934e-03+0.j,
#        5.09314060e-03+0.j, 4.25874540e-03+0.j, 3.54465505e-03+0.j,
#        2.93619322e-03+0.j, 2.41998971e-03+0.j, 1.98395194e-03+0.j,
#        1.61721855e-03+0.j, 1.31009925e-03+0.j, 1.05400438e-03+0.j,
#        8.41367758e-04+0.j, 6.65565390e-04+0.j, 5.20832744e-04+0.j,
#        4.02182462e-04+0.j, 3.05324208e-04+0.j, 2.26587930e-04+0.j,
#        1.62851445e-04+0.j, 1.11473038e-04+0.j, 7.02294350e-05+0.j,
#        3.72593612e-05+0.j, 1.10126838e-05+0.j])},
#                    {'name': '7556c3c0a5da99410b9a75768a4373112ab3e08202af4229abea2b7aaab9b740',
#                     'samples': array([1.20138369e-05+0.j, 4.06465758e-05+0.j, 7.66139291e-05+0.j,
#        1.21606951e-04+0.j, 1.77656122e-04+0.j, 2.47186832e-04+0.j,
#        3.33080955e-04+0.j, 4.38744504e-04+0.j, 5.68181176e-04+0.j,
#        7.26071335e-04+0.j, 9.17855736e-04+0.j, 1.14982296e-03+0.j,
#        1.42919918e-03+0.j, 1.76423842e-03+0.j, 2.16431120e-03+0.j,
#        2.63998877e-03+0.j, 3.20311987e-03+0.j, 3.86689641e-03+0.j,
#        4.64590408e-03+0.j, 5.55615338e-03+0.j, 6.61508655e-03+0.j,
#        7.84155521e-03+0.j, 9.25576389e-03+0.j, 1.08791744e-02+0.j,
#        1.27343666e-02+0.j, 1.48448501e-02+0.j, 1.72348261e-02+0.j,
#        1.99288927e-02+0.j, 2.29516956e-02+0.j, 2.63275228e-02+0.j,
#        3.00798440e-02+0.j, 3.42307992e-02+0.j, 3.88006411e-02+0.j,
#        4.38071395e-02+0.j, 4.92649558e-02+0.j, 5.51850011e-02+0.j,
#        6.15737896e-02+0.j, 6.84328052e-02+0.j, 7.57578960e-02+0.j,
#        8.35387164e-02+0.j, 9.17582360e-02+0.j, 1.00392333e-01+0.j,
#        1.09409493e-01+0.j, 1.18770627e-01+0.j, 1.28429030e-01+0.j,
#        1.38330489e-01+0.j, 1.48413551e-01+0.j, 1.58609961e-01+0.j,
#        1.68845268e-01+0.j, 1.79039600e-01+0.j, 1.89108598e-01+0.j,
#        1.98964500e-01+0.j, 2.08517354e-01+0.j, 2.17676343e-01+0.j,
#        2.26351192e-01+0.j, 2.34453628e-01+0.j, 2.41898861e-01+0.j,
#        2.48607056e-01+0.j, 2.54504751e-01+0.j, 2.59526194e-01+0.j,
#        2.63614564e-01+0.j, 2.66723037e-01+0.j, 2.68815683e-01+0.j,
#        2.69868152e-01+0.j, 2.69868152e-01+0.j, 2.68815683e-01+0.j,
#        2.66723037e-01+0.j, 2.63614564e-01+0.j, 2.59526194e-01+0.j,
#        2.54504751e-01+0.j, 2.48607056e-01+0.j, 2.41898861e-01+0.j,
#        2.34453628e-01+0.j, 2.26351192e-01+0.j, 2.17676343e-01+0.j,
#        2.08517354e-01+0.j, 1.98964500e-01+0.j, 1.89108598e-01+0.j,
#        1.79039600e-01+0.j, 1.68845268e-01+0.j, 1.58609961e-01+0.j,
#        1.48413551e-01+0.j, 1.38330489e-01+0.j, 1.28429030e-01+0.j,
#        1.18770627e-01+0.j, 1.09409493e-01+0.j, 1.00392333e-01+0.j,
#        9.17582360e-02+0.j, 8.35387164e-02+0.j, 7.57578960e-02+0.j,
#        6.84328052e-02+0.j, 6.15737896e-02+0.j, 5.51850011e-02+0.j,
#        4.92649558e-02+0.j, 4.38071395e-02+0.j, 3.88006411e-02+0.j,
#        3.42307992e-02+0.j, 3.00798440e-02+0.j, 2.63275228e-02+0.j,
#        2.29516956e-02+0.j, 1.99288927e-02+0.j, 1.72348261e-02+0.j,
#        1.48448501e-02+0.j, 1.27343666e-02+0.j, 1.08791744e-02+0.j,
#        9.25576389e-03+0.j, 7.84155521e-03+0.j, 6.61508655e-03+0.j,
#        5.55615338e-03+0.j, 4.64590408e-03+0.j, 3.86689641e-03+0.j,
#        3.20311987e-03+0.j, 2.63998877e-03+0.j, 2.16431120e-03+0.j,
#        1.76423842e-03+0.j, 1.42919918e-03+0.j, 1.14982296e-03+0.j,
#        9.17855736e-04+0.j, 7.26071335e-04+0.j, 5.68181176e-04+0.j,
#        4.38744504e-04+0.j, 3.33080955e-04+0.j, 2.47186832e-04+0.j,
#        1.77656122e-04+0.j, 1.21606951e-04+0.j, 7.66139291e-05+0.j,
#        4.06465758e-05+0.j, 1.20138369e-05+0.j])},
#                    {'name': '74cc91662659735e5b341bc0afeaf7ac112ec951d097466c9a8436d6effb7d8c',
#                     'samples': array([1.30149899e-05+0.j, 4.40337905e-05+0.j, 8.29984231e-05+0.j,
#        1.31740863e-04+0.j, 1.92460799e-04+0.j, 2.67785735e-04+0.j,
#        3.60837701e-04+0.j, 4.75306546e-04+0.j, 6.15529607e-04+0.j,
#        7.86577279e-04+0.j, 9.94343714e-04+0.j, 1.24564154e-03+0.j,
#        1.54829911e-03+0.j, 1.91125829e-03+0.j, 2.34467047e-03+0.j,
#        2.85998784e-03+0.j, 3.47004653e-03+0.j, 4.18913778e-03+0.j,
#        5.03306275e-03+0.j, 6.01916616e-03+0.j, 7.16634377e-03+0.j,
#        8.49501814e-03+0.j, 1.00270775e-02+0.j, 1.17857723e-02+0.j,
#        1.37955638e-02+0.j, 1.60819210e-02+0.j, 1.86710616e-02+0.j,
#        2.15896337e-02+0.j, 2.48643369e-02+0.j, 2.85214831e-02+0.j,
#        3.25864977e-02+0.j, 3.70833658e-02+0.j, 4.20340278e-02+0.j,
#        4.74577344e-02+0.j, 5.33703688e-02+0.j, 5.97837511e-02+0.j,
#        6.67049388e-02+0.j, 7.41355390e-02+0.j, 8.20710540e-02+0.j,
#        9.05002761e-02+0.j, 9.94047557e-02+0.j, 1.08758361e-01+0.j,
#        1.18526951e-01+0.j, 1.28668179e-01+0.j, 1.39131449e-01+0.j,
#        1.49858030e-01+0.j, 1.60781347e-01+0.j, 1.71827458e-01+0.j,
#        1.82915707e-01+0.j, 1.93959567e-01+0.j, 2.04867648e-01+0.j,
#        2.15544875e-01+0.j, 2.25893800e-01+0.j, 2.35816038e-01+0.j,
#        2.45213791e-01+0.j, 2.53991430e-01+0.j, 2.62057099e-01+0.j,
#        2.69324311e-01+0.j, 2.75713480e-01+0.j, 2.81153377e-01+0.j,
#        2.85582444e-01+0.j, 2.88949957e-01+0.j, 2.91216989e-01+0.j,
#        2.92357165e-01+0.j, 2.92357165e-01+0.j, 2.91216989e-01+0.j,
#        2.88949957e-01+0.j, 2.85582444e-01+0.j, 2.81153377e-01+0.j,
#        2.75713480e-01+0.j, 2.69324311e-01+0.j, 2.62057099e-01+0.j,
#        2.53991430e-01+0.j, 2.45213791e-01+0.j, 2.35816038e-01+0.j,
#        2.25893800e-01+0.j, 2.15544875e-01+0.j, 2.04867648e-01+0.j,
#        1.93959567e-01+0.j, 1.82915707e-01+0.j, 1.71827458e-01+0.j,
#        1.60781347e-01+0.j, 1.49858030e-01+0.j, 1.39131449e-01+0.j,
#        1.28668179e-01+0.j, 1.18526951e-01+0.j, 1.08758361e-01+0.j,
#        9.94047557e-02+0.j, 9.05002761e-02+0.j, 8.20710540e-02+0.j,
#        7.41355390e-02+0.j, 6.67049388e-02+0.j, 5.97837511e-02+0.j,
#        5.33703688e-02+0.j, 4.74577344e-02+0.j, 4.20340278e-02+0.j,
#        3.70833658e-02+0.j, 3.25864977e-02+0.j, 2.85214831e-02+0.j,
#        2.48643369e-02+0.j, 2.15896337e-02+0.j, 1.86710616e-02+0.j,
#        1.60819210e-02+0.j, 1.37955638e-02+0.j, 1.17857723e-02+0.j,
#        1.00270775e-02+0.j, 8.49501814e-03+0.j, 7.16634377e-03+0.j,
#        6.01916616e-03+0.j, 5.03306275e-03+0.j, 4.18913778e-03+0.j,
#        3.47004653e-03+0.j, 2.85998784e-03+0.j, 2.34467047e-03+0.j,
#        1.91125829e-03+0.j, 1.54829911e-03+0.j, 1.24564154e-03+0.j,
#        9.94343714e-04+0.j, 7.86577279e-04+0.j, 6.15529607e-04+0.j,
#        4.75306546e-04+0.j, 3.60837701e-04+0.j, 2.67785735e-04+0.j,
#        1.92460799e-04+0.j, 1.31740863e-04+0.j, 8.29984231e-05+0.j,
#        4.40337905e-05+0.j, 1.30149899e-05+0.j])},
#                    {'name': 'ca9ea367a57735b70b355e1256edb0fcf3c44abb420aa8307dd1dc3d6cc44c68',
#                     'samples': array([1.40161430e-05+0.j, 4.74210051e-05+0.j, 8.93829172e-05+0.j,
#        1.41874776e-04+0.j, 2.07265476e-04+0.j, 2.88384638e-04+0.j,
#        3.88594447e-04+0.j, 5.11868587e-04+0.j, 6.62878038e-04+0.j,
#        8.47083224e-04+0.j, 1.07083169e-03+0.j, 1.34146012e-03+0.j,
#        1.66739904e-03+0.j, 2.05827816e-03+0.j, 2.52502974e-03+0.j,
#        3.07998690e-03+0.j, 3.73697318e-03+0.j, 4.51137915e-03+0.j,
#        5.42022142e-03+0.j, 6.48217895e-03+0.j, 7.71760098e-03+0.j,
#        9.14848108e-03+0.j, 1.07983912e-02+0.j, 1.26923702e-02+0.j,
#        1.48567610e-02+0.j, 1.73189918e-02+0.j, 2.01072971e-02+0.j,
#        2.32503748e-02+0.j, 2.67769782e-02+0.j, 3.07154433e-02+0.j,
#        3.50931514e-02+0.j, 3.99359324e-02+0.j, 4.52674146e-02+0.j,
#        5.11083294e-02+0.j, 5.74757818e-02+0.j, 6.43825012e-02+0.j,
#        7.18360879e-02+0.j, 7.98382728e-02+0.j, 8.83842120e-02+0.j,
#        9.74618358e-02+0.j, 1.07051275e-01+0.j, 1.17124389e-01+0.j,
#        1.27644408e-01+0.j, 1.38565731e-01+0.j, 1.49833868e-01+0.j,
#        1.61385570e-01+0.j, 1.73149143e-01+0.j, 1.85044955e-01+0.j,
#        1.96986146e-01+0.j, 2.08879534e-01+0.j, 2.20626698e-01+0.j,
#        2.32125250e-01+0.j, 2.43270246e-01+0.j, 2.53955734e-01+0.j,
#        2.64076391e-01+0.j, 2.73529232e-01+0.j, 2.82215338e-01+0.j,
#        2.90041565e-01+0.j, 2.96922209e-01+0.j, 3.02780560e-01+0.j,
#        3.07550325e-01+0.j, 3.11176877e-01+0.j, 3.13618296e-01+0.j,
#        3.14846177e-01+0.j, 3.14846177e-01+0.j, 3.13618296e-01+0.j,
#        3.11176877e-01+0.j, 3.07550325e-01+0.j, 3.02780560e-01+0.j,
#        2.96922209e-01+0.j, 2.90041565e-01+0.j, 2.82215338e-01+0.j,
#        2.73529232e-01+0.j, 2.64076391e-01+0.j, 2.53955734e-01+0.j,
#        2.43270246e-01+0.j, 2.32125250e-01+0.j, 2.20626698e-01+0.j,
#        2.08879534e-01+0.j, 1.96986146e-01+0.j, 1.85044955e-01+0.j,
#        1.73149143e-01+0.j, 1.61385570e-01+0.j, 1.49833868e-01+0.j,
#        1.38565731e-01+0.j, 1.27644408e-01+0.j, 1.17124389e-01+0.j,
#        1.07051275e-01+0.j, 9.74618358e-02+0.j, 8.83842120e-02+0.j,
#        7.98382728e-02+0.j, 7.18360879e-02+0.j, 6.43825012e-02+0.j,
#        5.74757818e-02+0.j, 5.11083294e-02+0.j, 4.52674146e-02+0.j,
#        3.99359324e-02+0.j, 3.50931514e-02+0.j, 3.07154433e-02+0.j,
#        2.67769782e-02+0.j, 2.32503748e-02+0.j, 2.01072971e-02+0.j,
#        1.73189918e-02+0.j, 1.48567610e-02+0.j, 1.26923702e-02+0.j,
#        1.07983912e-02+0.j, 9.14848108e-03+0.j, 7.71760098e-03+0.j,
#        6.48217895e-03+0.j, 5.42022142e-03+0.j, 4.51137915e-03+0.j,
#        3.73697318e-03+0.j, 3.07998690e-03+0.j, 2.52502974e-03+0.j,
#        2.05827816e-03+0.j, 1.66739904e-03+0.j, 1.34146012e-03+0.j,
#        1.07083169e-03+0.j, 8.47083224e-04+0.j, 6.62878038e-04+0.j,
#        5.11868587e-04+0.j, 3.88594447e-04+0.j, 2.88384638e-04+0.j,
#        2.07265476e-04+0.j, 1.41874776e-04+0.j, 8.93829172e-05+0.j,
#        4.74210051e-05+0.j, 1.40161430e-05+0.j])},
#                    {'name': '82069c875762211acf86f8601f8d038a83f353ed0ddd1052db7bd67b6056a895',
#                     'samples': array([1.50172961e-05+0.j, 5.08082198e-05+0.j, 9.57674113e-05+0.j,
#        1.52008688e-04+0.j, 2.22070152e-04+0.j, 3.08983540e-04+0.j,
#        4.16351193e-04+0.j, 5.48430629e-04+0.j, 7.10226469e-04+0.j,
#        9.07589168e-04+0.j, 1.14731967e-03+0.j, 1.43727870e-03+0.j,
#        1.78649897e-03+0.j, 2.20529802e-03+0.j, 2.70538900e-03+0.j,
#        3.29998597e-03+0.j, 4.00389984e-03+0.j, 4.83362052e-03+0.j,
#        5.80738009e-03+0.j, 6.94519173e-03+0.j, 8.26885819e-03+0.j,
#        9.80194401e-03+0.j, 1.15697049e-02+0.j, 1.35989681e-02+0.j,
#        1.59179582e-02+0.j, 1.85560627e-02+0.j, 2.15435327e-02+0.j,
#        2.49111158e-02+0.j, 2.86896195e-02+0.j, 3.29094036e-02+0.j,
#        3.75998050e-02+0.j, 4.27884990e-02+0.j, 4.85008014e-02+0.j,
#        5.47589243e-02+0.j, 6.15811948e-02+0.j, 6.89812513e-02+0.j,
#        7.69672370e-02+0.j, 8.55410066e-02+0.j, 9.46973700e-02+0.j,
#        1.04423395e-01+0.j, 1.14697795e-01+0.j, 1.25490416e-01+0.j,
#        1.36761866e-01+0.j, 1.48463284e-01+0.j, 1.60536288e-01+0.j,
#        1.72913111e-01+0.j, 1.85516939e-01+0.j, 1.98262451e-01+0.j,
#        2.11056585e-01+0.j, 2.23799500e-01+0.j, 2.36385748e-01+0.j,
#        2.48705625e-01+0.j, 2.60646692e-01+0.j, 2.72095429e-01+0.j,
#        2.82938990e-01+0.j, 2.93067035e-01+0.j, 3.02373576e-01+0.j,
#        3.10758820e-01+0.j, 3.18130939e-01+0.j, 3.24407743e-01+0.j,
#        3.29518205e-01+0.j, 3.33403797e-01+0.j, 3.36019603e-01+0.j,
#        3.37335190e-01+0.j, 3.37335190e-01+0.j, 3.36019603e-01+0.j,
#        3.33403797e-01+0.j, 3.29518205e-01+0.j, 3.24407743e-01+0.j,
#        3.18130939e-01+0.j, 3.10758820e-01+0.j, 3.02373576e-01+0.j,
#        2.93067035e-01+0.j, 2.82938990e-01+0.j, 2.72095429e-01+0.j,
#        2.60646692e-01+0.j, 2.48705625e-01+0.j, 2.36385748e-01+0.j,
#        2.23799500e-01+0.j, 2.11056585e-01+0.j, 1.98262451e-01+0.j,
#        1.85516939e-01+0.j, 1.72913111e-01+0.j, 1.60536288e-01+0.j,
#        1.48463284e-01+0.j, 1.36761866e-01+0.j, 1.25490416e-01+0.j,
#        1.14697795e-01+0.j, 1.04423395e-01+0.j, 9.46973700e-02+0.j,
#        8.55410066e-02+0.j, 7.69672370e-02+0.j, 6.89812513e-02+0.j,
#        6.15811948e-02+0.j, 5.47589243e-02+0.j, 4.85008014e-02+0.j,
#        4.27884990e-02+0.j, 3.75998050e-02+0.j, 3.29094036e-02+0.j,
#        2.86896195e-02+0.j, 2.49111158e-02+0.j, 2.15435327e-02+0.j,
#        1.85560627e-02+0.j, 1.59179582e-02+0.j, 1.35989681e-02+0.j,
#        1.15697049e-02+0.j, 9.80194401e-03+0.j, 8.26885819e-03+0.j,
#        6.94519173e-03+0.j, 5.80738009e-03+0.j, 4.83362052e-03+0.j,
#        4.00389984e-03+0.j, 3.29998597e-03+0.j, 2.70538900e-03+0.j,
#        2.20529802e-03+0.j, 1.78649897e-03+0.j, 1.43727870e-03+0.j,
#        1.14731967e-03+0.j, 9.07589168e-04+0.j, 7.10226469e-04+0.j,
#        5.48430629e-04+0.j, 4.16351193e-04+0.j, 3.08983540e-04+0.j,
#        2.22070152e-04+0.j, 1.52008688e-04+0.j, 9.57674113e-05+0.j,
#        5.08082198e-05+0.j, 1.50172961e-05+0.j])},
#                    {'name': '01076da9b0f86cb9ee457e0dcbf7b96a193895e53f4017ad0ffaf3cb9c4929b3',
#                     'samples': array([1.60184491e-05+0.j, 5.41954344e-05+0.j, 1.02151905e-04+0.j,
#        1.62142601e-04+0.j, 2.36874829e-04+0.j, 3.29582443e-04+0.j,
#        4.44107939e-04+0.j, 5.84992671e-04+0.j, 7.57574901e-04+0.j,
#        9.68095113e-04+0.j, 1.22380765e-03+0.j, 1.53309728e-03+0.j,
#        1.90559890e-03+0.j, 2.35231789e-03+0.j, 2.88574827e-03+0.j,
#        3.51998503e-03+0.j, 4.27082650e-03+0.j, 5.15586188e-03+0.j,
#        6.19453877e-03+0.j, 7.40820451e-03+0.j, 8.82011540e-03+0.j,
#        1.04554069e-02+0.j, 1.23410185e-02+0.j, 1.45055659e-02+0.j,
#        1.69791554e-02+0.j, 1.97931335e-02+0.j, 2.29797682e-02+0.j,
#        2.65718569e-02+0.j, 3.06022608e-02+0.j, 3.51033638e-02+0.j,
#        4.01064587e-02+0.j, 4.56410656e-02+0.j, 5.17341881e-02+0.j,
#        5.84095193e-02+0.j, 6.56866077e-02+0.j, 7.35800014e-02+0.j,
#        8.20983862e-02+0.j, 9.12437403e-02+0.j, 1.01010528e-01+0.j,
#        1.11384955e-01+0.j, 1.22344315e-01+0.j, 1.33856444e-01+0.j,
#        1.45879324e-01+0.j, 1.58360836e-01+0.j, 1.71238707e-01+0.j,
#        1.84440652e-01+0.j, 1.97884735e-01+0.j, 2.11479948e-01+0.j,
#        2.25127024e-01+0.j, 2.38719467e-01+0.j, 2.52144798e-01+0.j,
#        2.65286000e-01+0.j, 2.78023138e-01+0.j, 2.90235124e-01+0.j,
# ...
#        2.28109351e-01+0.j, 2.05245965e-01+0.j, 1.83950004e-01+0.j,
#        1.64216519e-01+0.j, 1.46023798e-01+0.j, 1.29335470e-01+0.j,
#        1.14102664e-01+0.j, 1.00266147e-01+0.j, 8.77584095e-02+0.j,
#        7.65056520e-02+0.j, 6.64296422e-02+0.j, 5.74494204e-02+0.j,
#        4.94828338e-02+0.j, 4.24478885e-02+0.j, 3.62639148e-02+0.j,
#        3.08525463e-02+0.j, 2.61385174e-02+0.j, 2.20502885e-02+0.j,
#        1.85205113e-02+0.j, 1.54863469e-02+0.j, 1.28896547e-02+0.j,
#        1.06770662e-02+0.j, 8.79996258e-03+0.j, 7.21437068e-03+0.j,
#        5.88079473e-03+0.j, 4.76399726e-03+0.j, 3.83274321e-03+0.j,
#        3.05951912e-03+0.j, 2.42023778e-03+0.j, 1.89393725e-03+0.j,
#        1.46248168e-03+0.j, 1.11026985e-03+0.j, 8.23956108e-04+0.j,
#        5.92187073e-04+0.j, 4.05356502e-04+0.j, 2.55379764e-04+0.j,
#        1.35488586e-04+0.j, 4.00461229e-05+0.j])}],
#  'qubit_lo_freq': [5.042],
#  'shots': 512}
# Header: {'backend_name': 'pulse_simulator', 'backend_version': '0.5.1'}
# Experiments:
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: e5a00aa9991ac8a5ee3109844d84a55583bd20572ad3ffcd42792f3c36b183ad
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: d29c4b58ee50d741f45dda4f611c4829525a0629cd01a17c901b817ab61ea578
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 83833cc210b1d4c59348630cea5d8dec3025c7b0cc9a3fdfc243178250a7adec
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: e36898dd4bd900c403ac254e147ffcc2e2482ec5b1db6d40baa031d5c0e638a1
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 73bd08a80d4915c737b1e2777cfabc47b95f8b33c8d5737eb011fed4a2016fa3
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 250d72bae3d89db07ef44394a81b3f500347f738283635fb098820ad4893e8ea
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 292a2cd8e6a277c901b8fa5a84cbfc30d84efccee3482bf1c4f9e31756bd8e56
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: ded75b2df18cd745c5a951e575b95c32d187a5b24f9746f5a1c1d832a0548822
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 6b67e1514bbd671d7f1a0dbbabfafee9e2aab013d22f064151153577ca09dab9
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: fae8fe9315f837a9494eca3c9f2cb06e8adfc2dd96e020a655fba0c5ac8e19e3
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 3ff257d49fe236e3e0ba5a0a70cb98fecb1afd45df41b1c089b6e695cb6d985c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 36aa9699f197035fbc9df2f5243ee24d8017c37a517010a139f29837b6b6cfb9
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 7556c3c0a5da99410b9a75768a4373112ab3e08202af4229abea2b7aaab9b740
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 74cc91662659735e5b341bc0afeaf7ac112ec951d097466c9a8436d6effb7d8c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: ca9ea367a57735b70b355e1256edb0fcf3c44abb420aa8307dd1dc3d6cc44c68
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 82069c875762211acf86f8601f8d038a83f353ed0ddd1052db7bd67b6056a895
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 01076da9b0f86cb9ee457e0dcbf7b96a193895e53f4017ad0ffaf3cb9c4929b3
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 954f91b76670cc06e870bc9aa6de353f04f9d29781e7c0a0bc6696b650a1b928
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: d0963adb2fae6a810ad3aa59bcdada4dc34f06e243f4ec4b3f4a022d91ea7005
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 3f31f51add5986b1ce1e2e32ce4ab164783464c09efb34d300908c19b2d7d04b
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 8f54ffbfe70ad739790085a0c0cadc7a57ccabd66378d1e8ae2ac7b54bc53250
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 8f49d14eadaebfd2d9f9f7702c7209f5076a4305d6983f00bb2b26e246b2bd5c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: ce28710cbdcb148a0262a7dd6f59e64179db2f97a0ff5e76f1e003cf9b1ca71d
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 82f8f5ebf4970fa6b02ee1d2d8888e09eadcdfb787889590f7ca93aaa14ad169
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: e9c1ca7b5db5b7fa7673a46eaa0fa0f2850bb1bedb806360e3a0a57485c4a1a2
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 701ab5d436568a6f424b5521956fc85fe8e34cbe562e102037b3207e4f15752b
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 8db337e54914e1f291d6e49f1469f44869cc6a13320e74f0ed3800e9aa9e42d1
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 89083ba415abe02feab4546d34af01b92e6aebabbad87c77d076c0c23b451f14
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: b651721abb720f328b2a82d252fc3278c501ce179be48e308adf666d917f1bc2
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: d588bc3b1c408d4213f28e77cf4bdde09b1a08a16ba61b6663b2f2ecf47a89b7
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: fd6620773724e1ca6c017731ab4e62e59613b6fc10db9b90da1456cfd242c804
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 526df6b5886aded9f694e2af2c655e970d4c4412ca3d209045b4281d81ee4579
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: a838ddb524759decd7ee8a4ef8ea2abde8331453a5821dc239a2d39353765a06
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: fc5f884a856083a600b562bb86c4377b1279e1b830a962d62becaf767cb628e8
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 5d219e4cd20fb2799be5c1d2b8f65a09e0527c694b4ec4a4d945b130489b34e0
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 943897ca4fe0885ad1db8d14950e2992ec5550c88efb61242f236e18ba2034f1
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: e10bcb529c5a2f34b9090f584e679188d45da05adaf3500cb200a679a3123201
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 7d328ec2f4c142a6ef4147e74cbc30a6b2d0b4a5ba8583223c7ff992db0a1499
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 7c770bff2be7ab509f0617f1a9a2cc1ab926f99a20d31d511ef5374e9bc98a87
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 6590e6627ffd39943348396ca827f702abf18b0797f11c85afd631b7418a4c81
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'rabi_experiment'}
# Config:
# {}
#
# 	Instruction: 37a386a4aa32b49a1304a9ebf7ed7d5bcf7018e495c76a943b8da0e4cf94ae61
# 		t0: 0
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 128
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 128
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]

# %%
# run the simulation
rabi_result = backend_sim.run(rabi_qobj, duffing_model).result()

# %%
# retrieve the data from the experiment
rabi_values = helper.get_values_from_result(rabi_result, qubit)
print(rabi_values)
# Out:
# [0.0, 0.015625, 0.052734375, 0.125, 0.1796875, 0.275390625, 0.37109375, 0.51171875, 0.6328125, 0.744140625, 0.828125, 0.900390625, 0.958984375, 0.982421875, 0.998046875, 0.984375, 0.94140625, 0.88671875, 0.775390625, 0.673828125, 0.59375, 0.4765625, 0.34765625, 0.26171875, 0.16796875, 0.095703125, 0.02734375, 0.009765625, 0.0, 0.0234375, 0.0703125, 0.1015625, 0.232421875, 0.310546875, 0.47265625, 0.50390625, 0.654296875, 0.716796875, 0.80859375, 0.923828125, 0.95703125]

# %% [markdown]
# ### Fit Results and Plot Rabi Experiment
# Once the rough frequency of the qubit is know, the Rabi experiment determines the amplitude of a $\pi$-pulse, that is, the strength of a pulse needed to rotate the qubit around the Bloch sphere from the $|0\rangle$ to $|1\rangle$ states (or vice versa). We assume the rotation axis to be the $x$-axis.

# %%
fit_params, y_fit = helper.fit_sinusoid(drive_amps, rabi_values, [1, 0, 0.5, 0])

plt.scatter(drive_amps, rabi_values, color='white')
plt.plot(drive_amps, y_fit, color='red')

drive_period = fit_params[2] # get period of rabi oscillation

plt.axvline(0, color='red', linestyle='--')
plt.axvline(drive_period/2, color='red', linestyle='--')
plt.xlabel("Drive amp [a.u.]", fontsize=15)
plt.ylabel("Measured signal [a.u.]", fontsize=15)
plt.show()

print("Pi pulse amplitude is %f"%float(drive_period/2))
# Out:
# Pi pulse amplitude is 0.312724

# %% [markdown]
# The $\pi$ pulse amplitude is half the period of the sinusoid (a full period of $360^\circ$ brings it back to zero, but we wish to take the qubit from the zero to one state). For the following experiment, we want a $\pi/2$ pulse: we wish to place the qubit on the equator of the Bloch sphere. The following creates a pulse that rotates the qubit $\pi/2$ ($90^\circ$ degrees) around the Bloch sphere:

# %%
# x_90 is a concise way to say pi_over_2; i.e., an X rotation of 90 degrees
x90_pulse = pulse_lib.gaussian(duration=drive_duration,
                               amp=drive_period/4, 
                               sigma=drive_sigma,
                               name='x90_pulse')
print(x90_pulse)
# Out:
# SamplePulse(array([6.95742976e-06+0.j, 2.35391657e-05+0.j, 4.43685091e-05+0.j,
#        7.04247799e-05+0.j, 1.02883867e-04+0.j, 1.43150356e-04+0.j,
#        1.92893193e-04+0.j, 2.54084861e-04+0.j, 3.29043974e-04+0.j,
#        4.20481015e-04+0.j, 5.31546823e-04+0.j, 6.65883231e-04+0.j,
#        8.27675040e-04+0.j, 1.02170231e-03+0.j, 1.25339168e-03+0.j,
#        1.52886515e-03+0.j, 1.85498453e-03+0.j, 2.23938951e-03+0.j,
#        2.69052690e-03+0.j, 3.21766871e-03+0.j, 3.83091602e-03+0.j,
#        4.54118615e-03+0.j, 5.36017993e-03+0.j, 6.30032628e-03+0.j,
#        7.37470151e-03+0.j, 8.59692065e-03+0.j, 9.98099888e-03+0.j,
#        1.15411814e-02+0.j, 1.32917412e-02+0.j, 1.52467437e-02+0.j,
#        1.74197806e-02+0.j, 1.98236736e-02+0.j, 2.24701516e-02+0.j,
#        2.53695051e-02+0.j, 2.85302251e-02+0.j, 3.19586301e-02+0.j,
#        3.56584929e-02+0.j, 3.96306727e-02+0.j, 4.38727649e-02+0.j,
#        4.83787784e-02+0.j, 5.31388506e-02+0.j, 5.81390121e-02+0.j,
#        6.33610121e-02+0.j, 6.87822137e-02+0.j, 7.43755693e-02+0.j,
#        8.01096829e-02+0.j, 8.59489661e-02+0.j, 9.18538912e-02+0.j,
#        9.77813423e-02+0.j, 1.03685064e-01+0.j, 1.09516202e-01+0.j,
#        1.15223933e-01+0.j, 1.20756163e-01+0.j, 1.26060299e-01+0.j,
#        1.31084061e-01+0.j, 1.35776327e-01+0.j, 1.40087996e-01+0.j,
#        1.43972833e-01+0.j, 1.47388295e-01+0.j, 1.50296303e-01+0.j,
#        1.52663952e-01+0.j, 1.54464125e-01+0.j, 1.55676014e-01+0.j,
#        1.56285518e-01+0.j, 1.56285518e-01+0.j, 1.55676014e-01+0.j,
#        1.54464125e-01+0.j, 1.52663952e-01+0.j, 1.50296303e-01+0.j,
#        1.47388295e-01+0.j, 1.43972833e-01+0.j, 1.40087996e-01+0.j,
#        1.35776327e-01+0.j, 1.31084061e-01+0.j, 1.26060299e-01+0.j,
#        1.20756163e-01+0.j, 1.15223933e-01+0.j, 1.09516202e-01+0.j,
#        1.03685064e-01+0.j, 9.77813423e-02+0.j, 9.18538912e-02+0.j,
#        8.59489661e-02+0.j, 8.01096829e-02+0.j, 7.43755693e-02+0.j,
#        6.87822137e-02+0.j, 6.33610121e-02+0.j, 5.81390121e-02+0.j,
#        5.31388506e-02+0.j, 4.83787784e-02+0.j, 4.38727649e-02+0.j,
#        3.96306727e-02+0.j, 3.56584929e-02+0.j, 3.19586301e-02+0.j,
#        2.85302251e-02+0.j, 2.53695051e-02+0.j, 2.24701516e-02+0.j,
#        1.98236736e-02+0.j, 1.74197806e-02+0.j, 1.52467437e-02+0.j,
#        1.32917412e-02+0.j, 1.15411814e-02+0.j, 9.98099888e-03+0.j,
#        8.59692065e-03+0.j, 7.37470151e-03+0.j, 6.30032628e-03+0.j,
#        5.36017993e-03+0.j, 4.54118615e-03+0.j, 3.83091602e-03+0.j,
#        3.21766871e-03+0.j, 2.69052690e-03+0.j, 2.23938951e-03+0.j,
#        1.85498453e-03+0.j, 1.52886515e-03+0.j, 1.25339168e-03+0.j,
#        1.02170231e-03+0.j, 8.27675040e-04+0.j, 6.65883231e-04+0.j,
#        5.31546823e-04+0.j, 4.20481015e-04+0.j, 3.29043974e-04+0.j,
#        2.54084861e-04+0.j, 1.92893193e-04+0.j, 1.43150356e-04+0.j,
#        1.02883867e-04+0.j, 7.04247799e-05+0.j, 4.43685091e-05+0.j,
#        2.35391657e-05+0.j, 6.95742976e-06+0.j]), name='x90_pulse')

# %%
# Ramsey experiment parameters
time_max_us = 0.4
time_step_us = 0.0035
times_us = np.arange(0.1, time_max_us, time_step_us)
# Convert to units of dt
delay_times_dt = times_us * us / dt

# %% [markdown]
# ## Graded Exercise 1b: Ramsey Schedule
#
# Add code to the method below in order to build a Ramsey pulse schedule. For a review of creating pulse schedules, see [Lab 6 notebook](lab6-drive-ham-rabi-ramsey.ipynb).

# %%
def build_ramsey_pulse_schedule(delay):
    ### create a Ramsey pulse schedule (already done)
    ### play an x90 pulse on the drive channel
    ### play another x90 pulse after delay
    ### add measurement pulse to schedule
    
    ramsey_schedule = pulse.Schedule(name='ramsey_experiment')
    
    ### HINT: include delay by adding it to the duration of the schedule
    ###       round delay to nearest integer with int(delay)
    
    ### WRITE YOUR CODE BETWEEN THESE LINES - START
    ramsey_schedule += Play(x90_pulse, drive_chan)
    ramsey_schedule += Play(x90_pulse, drive_chan) << ramsey_schedule.duration + int(delay)
    ramsey_schedule += measure << ramsey_schedule.duration
    
    ### WRITE YOUR CODE BETWEEN THESE LINES - END
    
    return ramsey_schedule

# %%
# create schedules for Ramsey experiment 
ramsey_schedules = []
for delay in delay_times_dt:
    ramsey_schedules.append(build_ramsey_pulse_schedule(delay))

# %%
ramsey_schedules[-1].draw()

# %%
# assemble the schedules into a Qobj
# the helper will drive the pulses off-resonantly by an unknown value
ramsey_qobj = assemble(**helper.get_params('ramsey', globals()))
answer1b = ramsey_qobj
print(answer1b)
# Out:
# Pulse Qobj: 714cbaf6-fd8c-4ff7-b411-fbf3d56227ac:
# Config: {'meas_level': 1,
#  'meas_lo_freq': [inf],
#  'meas_return': 'avg',
#  'memory': False,
#  'memory_slot_size': 100,
#  'memory_slots': 1,
#  'parametric_pulses': [],
#  'pulse_library': [{'name': '2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c',
#                     'samples': array([6.95742976e-06+0.j, 2.35391657e-05+0.j, 4.43685091e-05+0.j,
#        7.04247799e-05+0.j, 1.02883867e-04+0.j, 1.43150356e-04+0.j,
#        1.92893193e-04+0.j, 2.54084861e-04+0.j, 3.29043974e-04+0.j,
#        4.20481015e-04+0.j, 5.31546823e-04+0.j, 6.65883231e-04+0.j,
#        8.27675040e-04+0.j, 1.02170231e-03+0.j, 1.25339168e-03+0.j,
#        1.52886515e-03+0.j, 1.85498453e-03+0.j, 2.23938951e-03+0.j,
#        2.69052690e-03+0.j, 3.21766871e-03+0.j, 3.83091602e-03+0.j,
#        4.54118615e-03+0.j, 5.36017993e-03+0.j, 6.30032628e-03+0.j,
#        7.37470151e-03+0.j, 8.59692065e-03+0.j, 9.98099888e-03+0.j,
#        1.15411814e-02+0.j, 1.32917412e-02+0.j, 1.52467437e-02+0.j,
#        1.74197806e-02+0.j, 1.98236736e-02+0.j, 2.24701516e-02+0.j,
#        2.53695051e-02+0.j, 2.85302251e-02+0.j, 3.19586301e-02+0.j,
#        3.56584929e-02+0.j, 3.96306727e-02+0.j, 4.38727649e-02+0.j,
#        4.83787784e-02+0.j, 5.31388506e-02+0.j, 5.81390121e-02+0.j,
#        6.33610121e-02+0.j, 6.87822137e-02+0.j, 7.43755693e-02+0.j,
#        8.01096829e-02+0.j, 8.59489661e-02+0.j, 9.18538912e-02+0.j,
#        9.77813423e-02+0.j, 1.03685064e-01+0.j, 1.09516202e-01+0.j,
#        1.15223933e-01+0.j, 1.20756163e-01+0.j, 1.26060299e-01+0.j,
#        1.31084061e-01+0.j, 1.35776327e-01+0.j, 1.40087996e-01+0.j,
#        1.43972833e-01+0.j, 1.47388295e-01+0.j, 1.50296303e-01+0.j,
#        1.52663952e-01+0.j, 1.54464125e-01+0.j, 1.55676014e-01+0.j,
#        1.56285518e-01+0.j, 1.56285518e-01+0.j, 1.55676014e-01+0.j,
#        1.54464125e-01+0.j, 1.52663952e-01+0.j, 1.50296303e-01+0.j,
#        1.47388295e-01+0.j, 1.43972833e-01+0.j, 1.40087996e-01+0.j,
#        1.35776327e-01+0.j, 1.31084061e-01+0.j, 1.26060299e-01+0.j,
#        1.20756163e-01+0.j, 1.15223933e-01+0.j, 1.09516202e-01+0.j,
#        1.03685064e-01+0.j, 9.77813423e-02+0.j, 9.18538912e-02+0.j,
#        8.59489661e-02+0.j, 8.01096829e-02+0.j, 7.43755693e-02+0.j,
#        6.87822137e-02+0.j, 6.33610121e-02+0.j, 5.81390121e-02+0.j,
#        5.31388506e-02+0.j, 4.83787784e-02+0.j, 4.38727649e-02+0.j,
#        3.96306727e-02+0.j, 3.56584929e-02+0.j, 3.19586301e-02+0.j,
#        2.85302251e-02+0.j, 2.53695051e-02+0.j, 2.24701516e-02+0.j,
#        1.98236736e-02+0.j, 1.74197806e-02+0.j, 1.52467437e-02+0.j,
#        1.32917412e-02+0.j, 1.15411814e-02+0.j, 9.98099888e-03+0.j,
#        8.59692065e-03+0.j, 7.37470151e-03+0.j, 6.30032628e-03+0.j,
#        5.36017993e-03+0.j, 4.54118615e-03+0.j, 3.83091602e-03+0.j,
#        3.21766871e-03+0.j, 2.69052690e-03+0.j, 2.23938951e-03+0.j,
#        1.85498453e-03+0.j, 1.52886515e-03+0.j, 1.25339168e-03+0.j,
#        1.02170231e-03+0.j, 8.27675040e-04+0.j, 6.65883231e-04+0.j,
#        5.31546823e-04+0.j, 4.20481015e-04+0.j, 3.29043974e-04+0.j,
#        2.54084861e-04+0.j, 1.92893193e-04+0.j, 1.43150356e-04+0.j,
#        1.02883867e-04+0.j, 7.04247799e-05+0.j, 4.43685091e-05+0.j,
#        2.35391657e-05+0.j, 6.95742976e-06+0.j])},
#                    {'name': 'bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a',
#                     'samples': array([1.78453696e-10+0.j, 7.99773979e-10+0.j, 3.36717422e-09+0.j, ...,
#        3.36717422e-09+0.j, 7.99773979e-10+0.j, 1.78453696e-10+0.j])}],
#  'qubit_lo_freq': [5.050675309],
#  'shots': 512}
# Header: {'backend_name': 'pulse_simulator', 'backend_version': '0.5.1'}
# Experiments:
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 355
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 483
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 483
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 359
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 487
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 487
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 363
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 491
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 491
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 366
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 494
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 494
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 370
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 498
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 498
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 373
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 501
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 501
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 377
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 505
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 505
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 380
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 508
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 508
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 384
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 512
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 512
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 387
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 515
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 515
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 391
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 519
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 519
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 394
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 522
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 522
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 398
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 526
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 526
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 401
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 529
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 529
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 405
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 533
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 533
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 408
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 536
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 536
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 412
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 540
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 540
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 415
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 543
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 543
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 419
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 547
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 547
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 422
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 550
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 550
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 426
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 554
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 554
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 429
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 557
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 557
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 433
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 561
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 561
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 436
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 564
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 564
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 440
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 568
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 568
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 443
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 571
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 571
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 447
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 575
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 575
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 450
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 578
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 578
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 454
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 582
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 582
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 457
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 585
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 585
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 461
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 589
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 589
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 464
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 592
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 592
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 468
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 596
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 596
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 471
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 599
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 599
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 475
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 603
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 603
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 478
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 606
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 606
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 482
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 610
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 610
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 485
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 613
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 613
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 489
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 617
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 617
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 492
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 620
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 620
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 496
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 624
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 624
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 499
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 627
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 627
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 503
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 631
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 631
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 506
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 634
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 634
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 510
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 638
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 638
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 513
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 641
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 641
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 517
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 645
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 645
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 520
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 648
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 648
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 524
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 652
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 652
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 527
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 655
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 655
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 531
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 659
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 659
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 534
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 662
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 662
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 538
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 666
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 666
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 541
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 669
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 669
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 545
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 673
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 673
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 548
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 676
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 676
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 552
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 680
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 680
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 555
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 683
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 683
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 559
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 687
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 687
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 562
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 690
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 690
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 566
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 694
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 694
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 569
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 697
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 697
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 573
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 701
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 701
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 576
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 704
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 704
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 580
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 708
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 708
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 583
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 711
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 711
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 587
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 715
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 715
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 590
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 718
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 718
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 594
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 722
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 722
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 597
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 725
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 725
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 601
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 729
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 729
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 604
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 732
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 732
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 608
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 736
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 736
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 611
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 739
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 739
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 615
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 743
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 743
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 618
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 746
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 746
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 622
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 750
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 750
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 625
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 753
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 753
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 629
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 757
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 757
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 632
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 760
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 760
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 636
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 764
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 764
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 639
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 767
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 767
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 643
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 771
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 771
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 646
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 774
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 774
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 650
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 778
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 778
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]
#
#
# Pulse Experiment:
# Header:
# {'memory_slots': 1, 'name': 'ramsey_experiment'}
# Config:
# {}
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 0
# 		ch: d0
#
# 	Instruction: 2f67b36770664379fde83d12aa17c7fa20c52b46b6a682de3c76678d1177e85c
# 		t0: 653
# 		ch: d0
#
# 	Instruction: bd616d380f0f9e7a4b01204c5e92d4a113820e29202e9931a81908826a1a819a
# 		t0: 781
# 		ch: m0
#
# 	Instruction: acquire
# 		t0: 781
# 		duration: 1200
# 		qubits: [0]
# 		memory_slot: [0]

# %%
# run the simulation
ramsey_result = backend_sim.run(ramsey_qobj, duffing_model).result()

# %%
# retrieve the data from the experiment
ramsey_values = helper.get_values_from_result(ramsey_result, qubit)
print(ramsey_values)
# Out:
# [0.6171875, 0.48828125, 0.44140625, 0.41796875, 0.302734375, 0.25390625, 0.18359375, 0.119140625, 0.078125, 0.0546875, 0.01171875, 0.00390625, 0.00390625, 0.005859375, 0.02734375, 0.064453125, 0.111328125, 0.181640625, 0.201171875, 0.318359375, 0.353515625, 0.451171875, 0.482421875, 0.55078125, 0.615234375, 0.650390625, 0.677734375, 0.7265625, 0.685546875, 0.728515625, 0.736328125, 0.62890625, 0.611328125, 0.560546875, 0.509765625, 0.39453125, 0.388671875, 0.3515625, 0.2421875, 0.189453125, 0.126953125, 0.095703125, 0.0390625, 0.01171875, 0.001953125, 0.0, 0.017578125, 0.060546875, 0.083984375, 0.109375, 0.21875, 0.26171875, 0.310546875, 0.375, 0.447265625, 0.50390625, 0.537109375, 0.630859375, 0.6796875, 0.654296875, 0.724609375, 0.716796875, 0.732421875, 0.69140625, 0.65625, 0.59765625, 0.5234375, 0.4921875, 0.44921875, 0.359375, 0.326171875, 0.244140625, 0.158203125, 0.1328125, 0.08984375, 0.025390625, 0.015625, 0.0, 0.001953125, 0.01171875, 0.0390625, 0.076171875, 0.123046875, 0.150390625, 0.21875, 0.310546875]

# %%
# off-resonance component
fit_params, y_fit = helper.fit_sinusoid(times_us, ramsey_values, [1, 0.7, 0.1, 0.25])
_, _, ramsey_period_us, _, = fit_params 
del_f_MHz = 1/ramsey_period_us # freq is MHz since times in us

plt.scatter(times_us, np.real(ramsey_values), color='white')
plt.plot(times_us, y_fit, color='red', label=f"df = {del_f_MHz:.6f} MHz")
plt.xlim(np.min(times_us), np.max(times_us))
plt.xlabel('Delay between X90 pulses [$\mu$s]', fontsize=15)
plt.ylabel('Measured Signal [a.u.]', fontsize=15)
plt.title('Ramsey Experiment', fontsize=15)
plt.legend(loc=3)
plt.show()

print("Drive is off-resonant by %f MHz"%float(del_f_MHz))
# Out:
# Drive is off-resonant by 8.681819 MHz

# %% [markdown]
# Now grade your solutions by running the cell below. **Provide always the same name and email, as the one you wrote during the course sign up.**

# %%
name = 'Shovit Bhari'
email = 'shovitraj@gmail.com'

from grading_tools import grade
grade(answer1a, name, email, 'lab6', 'ex1a')
grade(answer1b, name, email, 'lab6', 'ex1b')
# Out:
# Grading...
# lab6/ex1a - 🎉 Correct
# 🎊 Hurray! You have a new correct answer! Let's submit it.
# Submitting the answers for lab6...
# 📝 Our records, so far, are:
# Correct answers: lab1:ex1, lab2:ex1, lab3:ex1, lab4:ex1, lab5:ex1, lab6:ex1a
# Grading...
# None ...Retrying with a fresh session...
# lab6/ex1b - 🎉 Correct
# 🎊 Hurray! You have a new correct answer! Let's submit it.
# Submitting the answers for lab6...
# 📝 Our records, so far, are:
# Correct answers: lab1:ex1, lab2:ex1, lab3:ex1, lab4:ex1, lab5:ex1, lab6:ex1a, lab6:ex1b

# %% [markdown]
# **Help us improve our educational tools by submitting your code**<br>
# If you would like to help us learn how to improve our educational materials and offerings, you can opt in to send us a copy of your Jupyter notebook. By executing the cell below, you consent to sending us the code in your Jupyter notebook. All of the personal information will be anonymized.

# %%
from IPython.display import display, Javascript;display(Javascript('IPython.notebook.save_checkpoint();'));
from grading_tools import send_code;send_code('ex1.ipynb')
# Out:
# Sending ex1.ipynb ...
# Sent. Thanks!

# %% [markdown]
# # Additional Resources
#
# - The Qiskit textbook sections that cover this material are
#   - [Introduction to Transmon Physics](https://qiskit.org/textbook/ch-quantum-hardware/transmon-physics.html)
#   - [Calibrating Qubits with Qiskit Pulse](https://qiskit.org/textbook/ch-quantum-hardware/calibrating-qubits-openpulse.html)
#
# - Watch the videos
#   - [Quantum Coding with Lauren Capelluto](https://www.youtube.com/watch?v=ZvipHRY-URs)
#   - ["Qiskit Pulse: Programming Quantum Computers Through the Cloud with Pulses"](https://www.youtube.com/watch?v=V_as5PufUiU) webinar at CQT by yours truly
