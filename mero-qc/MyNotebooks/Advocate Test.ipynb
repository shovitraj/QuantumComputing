# %% [markdown]
# # Question 1

# %% [markdown]
# Ans 3

# %% [markdown]
# # Question 2

# %%
from qiskit import *
from math import pi
import numpy as np
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_city

# %matplotlib inline

# %%
qc = QuantumCircuit(2,2)
# Apply H-gate to the first:
qc.h(0)
# Apply a CNOT:
qc.cx(0,1)
qc.barrier()
qc.measure([0, 1], [0, 1])
qc.draw('mpl')

# %%
# Let's see the result:
backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc,backend).result().get_statevector()
# Print the statevector neatly:
#array_to_latex(final_state, pretext="\\text{Statevector = }")
final_state
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j])

# %%
results = execute(qc,backend).result().get_counts()
plot_histogram(results)

# %% [markdown]
# # Question 3

# %%
qc3 = QuantumCircuit(3)
# Apply H-gate to the first:
qc3.h(0)
qc3.h(1)

# Apply a CNOT:
qc3.cx(0,1)
qc3.cx(0,2)
qc3.draw('mpl')

# %%
# Let's see the result:
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc3, backend).result()
plot_state_city(job.get_statevector(qc3), color=['midnightblue', 'midnightblue'],
     title="New State City")

# %% [markdown]
# ### Question 4

# %%
sv1 = Statevector.from_label('01')
plot_state_qsphere(sv1.data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-80140eed5d9f> in <module>
#       1 sv1 = Statevector.from_label('01')
# ----> 2 plot_state_qsphere(sv1.data)
#
# NameError: name 'plot_state_qsphere' is not defined
